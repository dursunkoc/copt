# %%
import numpy as np
import networkx as nx
from networkx.generators.random_graphs import erdos_renyi_graph, barabasi_albert_graph
import matplotlib.pyplot as plt
from pylab import *
import pandas as pd

# %%
def gen_network(p, n, m, net_type, drop_prob=None, seed=34) :
    if net_type == 'erdos':
        g = erdos_renyi_graph(n=n, p=p, seed=seed)
    elif net_type == 'barabasi':
        g = barabasi_albert_graph(n=n, m=m, seed=seed)
    if drop_prob is not None:
        np.random.seed(seed)
        for e in g.edges:
            if np.random.random(size=1)<=drop_prob:
                g.remove_edge(e[0],e[1])
    N_i_j = nx.to_numpy_matrix(g, dtype=np.int0)

    return N_i_j, g

# %%
NUMBER_OF_CUSTOMERS = 35
NUMBER_OF_PRODUCTS = 10
SALES_PER_DAY = 1

# %%
# %%time
net,grp = gen_network(p=0,n=NUMBER_OF_CUSTOMERS, m=4, net_type='barabasi', drop_prob=None, seed=34)
# Out:
# Wall time: 1.98 ms

# %% [markdown]
# id, product, date

# %% [markdown]
# - For each Day
#     - Select a bunch of Random customer (np.choice())
#     - Select a bunch of Random products (np.choice())

# %%
customers = np.arange(NUMBER_OF_CUSTOMERS)
products = np.arange(NUMBER_OF_PRODUCTS)
start_date = np.datetime64('2017-01-01')
end_date = np.datetime64('2018-01-01')
theCalender = np.arange(start_date, end_date)

# %%
start_date = np.datetime64('2017-01')
end_date = np.datetime64('2018-01')
m_delta = np.timedelta64(1, 'M')
d_delta = np.timedelta64(1, 'D')
np.random.seed(34)
y_d = 1
data = []
for m in np.arange(start_date, end_date, m_delta):
    diff_range = np.arange(m, m+m_delta, d_delta)
    diff_range_size = diff_range.size
    selectedCustomers = np.random.choice(customers, diff_range_size*SALES_PER_DAY, replace=False)
    selectedProducts = np.random.choice(products, diff_range_size*SALES_PER_DAY, replace=True)
    d_i = 1
    for d in diff_range:
        cust = selectedCustomers[(d_i-1)*SALES_PER_DAY:d_i*SALES_PER_DAY]
        prd = selectedProducts[(d_i-1)*SALES_PER_DAY:d_i*SALES_PER_DAY]
        o = np.vstack((cust, prd, np.repeat(y_d, SALES_PER_DAY))).T
        data.append(o)
        d_i += 1
        y_d += 1

data = np.concatenate(data)
df = pd.DataFrame(data, columns=("cust","prd","date"))

# %%
display(df[df["cust"]==4].sort_values("prd"))
display(df[df["cust"]==0].sort_values("prd"))
# Out:
#      cust  prd  date
# 34      4    0    35
# 260     4    1   261
# 296     4    1   297
# 354     4    2   355
# 127     4    3   128
# 325     4    3   326
# 81      4    7    82
# 118     4    8   119
# 156     4    9   157
# 225     4    9   226
#      cust  prd  date
# 251     0    1   252
# 343     0    1   344
# 132     0    2   133
# 172     0    3   173
# 229     0    4   230
# 19      0    6    20
# 302     0    6   303
# 78      0    8    79
# 115     0    8   116
# 184     0    8   185

# %%
for i in range(0,NUMBER_OF_CUSTOMERS):
    for j in range(0, NUMBER_OF_CUSTOMERS):
        if net[i,j]==1:
            print(f"{(i,j)} ->\n")
            for p in range(0,NUMBER_OF_PRODUCTS):
                c1_sales = df[(df['cust']==i) & (df['prd']==p)]['date'].ravel()
                c2_sales = df[(df['cust']==j) & (df['prd']==p)]['date'].ravel()
                if c1_sales.size>0 and c2_sales.size>0:
                    sales_likely = np.sort([np.abs(c1-c2) for c1 in c1_sales for c2 in c2_sales])
                    likely_size = len(sales_likely)
                    likely_diff = sales_likely[0:3]
                    print(f"\tcust-{i} ~ cust-{j} ~ prod-{p} ==> size: {likely_size}, diffs:{likely_diff}")
# Out:
# (0, 1) ->
#
# 	cust-0 ~ cust-1 ~ prod-2 ==> size: 1, diffs:[207]
# 	cust-0 ~ cust-1 ~ prod-3 ==> size: 1, diffs:[10]
# 	cust-0 ~ cust-1 ~ prod-4 ==> size: 1, diffs:[65]
# 	cust-0 ~ cust-1 ~ prod-6 ==> size: 2, diffs:[ 25 258]
# 	cust-0 ~ cust-1 ~ prod-8 ==> size: 9, diffs:[ 2 10 27]
# (0, 2) ->
#
# 	cust-0 ~ cust-2 ~ prod-1 ==> size: 6, diffs:[14 25 78]
# 	cust-0 ~ cust-2 ~ prod-3 ==> size: 2, diffs:[ 49 112]
# 	cust-0 ~ cust-2 ~ prod-4 ==> size: 1, diffs:[221]
# 	cust-0 ~ cust-2 ~ prod-8 ==> size: 3, diffs:[140 209 246]
# (0, 3) ->
#
# 	cust-0 ~ cust-3 ~ prod-1 ==> size: 2, diffs:[ 39 131]
# 	cust-0 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[27]
# 	cust-0 ~ cust-3 ~ prod-3 ==> size: 1, diffs:[186]
# 	cust-0 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[21 56]
# 	cust-0 ~ cust-3 ~ prod-6 ==> size: 4, diffs:[ 38 115 168]
# (0, 4) ->
#
# 	cust-0 ~ cust-4 ~ prod-1 ==> size: 4, diffs:[ 9 45 47]
# 	cust-0 ~ cust-4 ~ prod-2 ==> size: 1, diffs:[222]
# 	cust-0 ~ cust-4 ~ prod-3 ==> size: 2, diffs:[ 45 153]
# 	cust-0 ~ cust-4 ~ prod-8 ==> size: 3, diffs:[ 3 40 66]
# (0, 5) ->
#
# 	cust-0 ~ cust-5 ~ prod-1 ==> size: 2, diffs:[ 97 189]
# 	cust-0 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[70]
# 	cust-0 ~ cust-5 ~ prod-3 ==> size: 1, diffs:[142]
# 	cust-0 ~ cust-5 ~ prod-6 ==> size: 6, diffs:[ 11  43 109]
# 	cust-0 ~ cust-5 ~ prod-8 ==> size: 6, diffs:[ 16  53 122]
# (0, 6) ->
#
# 	cust-0 ~ cust-6 ~ prod-1 ==> size: 4, diffs:[ 8 29 63]
# 	cust-0 ~ cust-6 ~ prod-3 ==> size: 1, diffs:[22]
# 	cust-0 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[206]
# 	cust-0 ~ cust-6 ~ prod-8 ==> size: 6, diffs:[ 69 138 149]
# (0, 7) ->
#
# 	cust-0 ~ cust-7 ~ prod-1 ==> size: 4, diffs:[13 63 79]
# 	cust-0 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[ 77 112]
# (0, 8) ->
#
# 	cust-0 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[125]
# 	cust-0 ~ cust-8 ~ prod-6 ==> size: 4, diffs:[ 25  48 235]
# 	cust-0 ~ cust-8 ~ prod-8 ==> size: 3, diffs:[176 245 282]
# (0, 10) ->
#
# 	cust-0 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[53 53]
# 	cust-0 ~ cust-10 ~ prod-3 ==> size: 1, diffs:[95]
# 	cust-0 ~ cust-10 ~ prod-4 ==> size: 3, diffs:[58 60 91]
# 	cust-0 ~ cust-10 ~ prod-6 ==> size: 2, diffs:[ 19 264]
# (0, 16) ->
#
# 	cust-0 ~ cust-16 ~ prod-6 ==> size: 6, diffs:[ 34  60 132]
# 	cust-0 ~ cust-16 ~ prod-8 ==> size: 9, diffs:[ 9 19 46]
# (0, 18) ->
#
# 	cust-0 ~ cust-18 ~ prod-1 ==> size: 8, diffs:[24 57 68]
# 	cust-0 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[7]
# 	cust-0 ~ cust-18 ~ prod-8 ==> size: 9, diffs:[ 1 36 38]
# (0, 21) ->
#
# 	cust-0 ~ cust-21 ~ prod-1 ==> size: 2, diffs:[196 288]
# 	cust-0 ~ cust-21 ~ prod-2 ==> size: 1, diffs:[31]
# 	cust-0 ~ cust-21 ~ prod-4 ==> size: 2, diffs:[ 28 113]
# 	cust-0 ~ cust-21 ~ prod-6 ==> size: 4, diffs:[ 89 127 156]
# (0, 24) ->
#
# 	cust-0 ~ cust-24 ~ prod-1 ==> size: 2, diffs:[ 20 112]
# 	cust-0 ~ cust-24 ~ prod-3 ==> size: 1, diffs:[119]
# 	cust-0 ~ cust-24 ~ prod-4 ==> size: 1, diffs:[205]
# 	cust-0 ~ cust-24 ~ prod-6 ==> size: 2, diffs:[105 178]
# 	cust-0 ~ cust-24 ~ prod-8 ==> size: 6, diffs:[16 31 53]
# (0, 25) ->
#
# 	cust-0 ~ cust-25 ~ prod-2 ==> size: 1, diffs:[107]
# 	cust-0 ~ cust-25 ~ prod-4 ==> size: 2, diffs:[ 24 122]
# (0, 30) ->
#
# 	cust-0 ~ cust-30 ~ prod-1 ==> size: 2, diffs:[ 33 125]
# 	cust-0 ~ cust-30 ~ prod-2 ==> size: 2, diffs:[35 64]
# 	cust-0 ~ cust-30 ~ prod-3 ==> size: 1, diffs:[83]
# 	cust-0 ~ cust-30 ~ prod-4 ==> size: 1, diffs:[89]
# 	cust-0 ~ cust-30 ~ prod-8 ==> size: 9, diffs:[42 58 79]
# (0, 34) ->
#
# 	cust-0 ~ cust-34 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-0 ~ cust-34 ~ prod-6 ==> size: 4, diffs:[ 54  84 199]
# (1, 0) ->
#
# 	cust-1 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[207]
# 	cust-1 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[10]
# 	cust-1 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[65]
# 	cust-1 ~ cust-0 ~ prod-6 ==> size: 2, diffs:[ 25 258]
# 	cust-1 ~ cust-0 ~ prod-8 ==> size: 9, diffs:[ 2 10 27]
# (1, 5) ->
#
# 	cust-1 ~ cust-5 ~ prod-0 ==> size: 3, diffs:[117 159 188]
# 	cust-1 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[137]
# 	cust-1 ~ cust-5 ~ prod-3 ==> size: 1, diffs:[152]
# 	cust-1 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[ 84 215 269]
# 	cust-1 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 72 268]
# 	cust-1 ~ cust-5 ~ prod-8 ==> size: 6, diffs:[26 55 61]
# (1, 6) ->
#
# 	cust-1 ~ cust-6 ~ prod-3 ==> size: 1, diffs:[32]
# 	cust-1 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[141]
# 	cust-1 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[60]
# 	cust-1 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[99]
# 	cust-1 ~ cust-6 ~ prod-8 ==> size: 6, diffs:[136 165 216]
# (1, 7) ->
#
# 	cust-1 ~ cust-7 ~ prod-0 ==> size: 6, diffs:[ 6 36 65]
# 	cust-1 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[ 87 102]
# 	cust-1 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[74]
# 	cust-1 ~ cust-7 ~ prod-7 ==> size: 1, diffs:[145]
# (1, 10) ->
#
# 	cust-1 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[154 260]
# 	cust-1 ~ cust-10 ~ prod-3 ==> size: 1, diffs:[85]
# 	cust-1 ~ cust-10 ~ prod-4 ==> size: 3, diffs:[  7 125 156]
# 	cust-1 ~ cust-10 ~ prod-5 ==> size: 2, diffs:[ 54 117]
# 	cust-1 ~ cust-10 ~ prod-6 ==> size: 1, diffs:[6]
# 	cust-1 ~ cust-10 ~ prod-7 ==> size: 1, diffs:[34]
# (1, 12) ->
#
# 	cust-1 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[17 94]
# 	cust-1 ~ cust-12 ~ prod-4 ==> size: 1, diffs:[155]
# 	cust-1 ~ cust-12 ~ prod-5 ==> size: 1, diffs:[88]
# 	cust-1 ~ cust-12 ~ prod-6 ==> size: 1, diffs:[1]
# 	cust-1 ~ cust-12 ~ prod-7 ==> size: 1, diffs:[15]
# 	cust-1 ~ cust-12 ~ prod-8 ==> size: 3, diffs:[10 19 97]
# (1, 13) ->
#
# 	cust-1 ~ cust-13 ~ prod-0 ==> size: 6, diffs:[11 31 38]
# 	cust-1 ~ cust-13 ~ prod-2 ==> size: 1, diffs:[36]
# 	cust-1 ~ cust-13 ~ prod-3 ==> size: 2, diffs:[ 73 171]
# 	cust-1 ~ cust-13 ~ prod-4 ==> size: 2, diffs:[17 33]
# 	cust-1 ~ cust-13 ~ prod-5 ==> size: 1, diffs:[94]
# 	cust-1 ~ cust-13 ~ prod-6 ==> size: 1, diffs:[21]
# 	cust-1 ~ cust-13 ~ prod-7 ==> size: 1, diffs:[94]
# 	cust-1 ~ cust-13 ~ prod-8 ==> size: 3, diffs:[211 240 327]
# (1, 14) ->
#
# 	cust-1 ~ cust-14 ~ prod-2 ==> size: 1, diffs:[187]
# 	cust-1 ~ cust-14 ~ prod-4 ==> size: 1, diffs:[133]
# 	cust-1 ~ cust-14 ~ prod-5 ==> size: 2, diffs:[61 83]
# 	cust-1 ~ cust-14 ~ prod-6 ==> size: 1, diffs:[288]
# 	cust-1 ~ cust-14 ~ prod-8 ==> size: 6, diffs:[27 56 60]
# (1, 17) ->
#
# 	cust-1 ~ cust-17 ~ prod-0 ==> size: 6, diffs:[ 8 37 79]
# 	cust-1 ~ cust-17 ~ prod-2 ==> size: 2, diffs:[ 67 180]
# 	cust-1 ~ cust-17 ~ prod-3 ==> size: 2, diffs:[112 122]
# 	cust-1 ~ cust-17 ~ prod-6 ==> size: 2, diffs:[28 90]
# 	cust-1 ~ cust-17 ~ prod-8 ==> size: 3, diffs:[110 139 226]
# (1, 28) ->
#
# 	cust-1 ~ cust-28 ~ prod-0 ==> size: 3, diffs:[106 148 177]
# 	cust-1 ~ cust-28 ~ prod-2 ==> size: 1, diffs:[191]
# 	cust-1 ~ cust-28 ~ prod-3 ==> size: 2, diffs:[ 27 129]
# 	cust-1 ~ cust-28 ~ prod-4 ==> size: 1, diffs:[130]
# 	cust-1 ~ cust-28 ~ prod-5 ==> size: 2, diffs:[12 98]
# 	cust-1 ~ cust-28 ~ prod-6 ==> size: 1, diffs:[33]
# 	cust-1 ~ cust-28 ~ prod-7 ==> size: 1, diffs:[293]
# (2, 0) ->
#
# 	cust-2 ~ cust-0 ~ prod-1 ==> size: 6, diffs:[14 25 78]
# 	cust-2 ~ cust-0 ~ prod-3 ==> size: 2, diffs:[ 49 112]
# 	cust-2 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[221]
# 	cust-2 ~ cust-0 ~ prod-8 ==> size: 3, diffs:[140 209 246]
# (2, 5) ->
#
# 	cust-2 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[238]
# 	cust-2 ~ cust-5 ~ prod-1 ==> size: 3, diffs:[ 12  72 111]
# 	cust-2 ~ cust-5 ~ prod-3 ==> size: 2, diffs:[30 93]
# 	cust-2 ~ cust-5 ~ prod-8 ==> size: 2, diffs:[ 22 262]
# 	cust-2 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[260]
# (2, 6) ->
#
# 	cust-2 ~ cust-6 ~ prod-1 ==> size: 6, diffs:[15 54 86]
# 	cust-2 ~ cust-6 ~ prod-3 ==> size: 2, diffs:[27 90]
# 	cust-2 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-2 ~ cust-6 ~ prod-5 ==> size: 2, diffs:[115 215]
# 	cust-2 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 9 71]
# (2, 8) ->
#
# 	cust-2 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[113 217]
# 	cust-2 ~ cust-8 ~ prod-8 ==> size: 1, diffs:[36]
# 	cust-2 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[258]
# (2, 21) ->
#
# 	cust-2 ~ cust-21 ~ prod-1 ==> size: 3, diffs:[111 171 210]
# 	cust-2 ~ cust-21 ~ prod-4 ==> size: 2, diffs:[193 334]
# 	cust-2 ~ cust-21 ~ prod-5 ==> size: 4, diffs:[ 7 34 66]
# 	cust-2 ~ cust-21 ~ prod-9 ==> size: 1, diffs:[267]
# (2, 32) ->
#
# 	cust-2 ~ cust-32 ~ prod-1 ==> size: 6, diffs:[ 3 19 42]
# 	cust-2 ~ cust-32 ~ prod-4 ==> size: 1, diffs:[4]
# 	cust-2 ~ cust-32 ~ prod-8 ==> size: 2, diffs:[ 70 289]
# (3, 0) ->
#
# 	cust-3 ~ cust-0 ~ prod-1 ==> size: 2, diffs:[ 39 131]
# 	cust-3 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[27]
# 	cust-3 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[186]
# 	cust-3 ~ cust-0 ~ prod-4 ==> size: 2, diffs:[21 56]
# 	cust-3 ~ cust-0 ~ prod-6 ==> size: 4, diffs:[ 38 115 168]
# (3, 5) ->
#
# 	cust-3 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[198]
# 	cust-3 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[58]
# 	cust-3 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[97]
# 	cust-3 ~ cust-5 ~ prod-3 ==> size: 1, diffs:[328]
# 	cust-3 ~ cust-5 ~ prod-6 ==> size: 6, diffs:[59 71 72]
# 	cust-3 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 79 275]
# 	cust-3 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[233]
# (3, 6) ->
#
# 	cust-3 ~ cust-6 ~ prod-1 ==> size: 2, diffs:[ 68 139]
# 	cust-3 ~ cust-6 ~ prod-3 ==> size: 1, diffs:[208]
# 	cust-3 ~ cust-6 ~ prod-4 ==> size: 2, diffs:[150 227]
# 	cust-3 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[106]
# (3, 7) ->
#
# 	cust-3 ~ cust-7 ~ prod-0 ==> size: 2, diffs:[ 75 293]
# 	cust-3 ~ cust-7 ~ prod-1 ==> size: 2, diffs:[24 52]
# 	cust-3 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[ 74 263]
# 	cust-3 ~ cust-7 ~ prod-7 ==> size: 1, diffs:[152]
# 	cust-3 ~ cust-7 ~ prod-9 ==> size: 2, diffs:[ 10 262]
# (3, 8) ->
#
# 	cust-3 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[ 73 177]
# 	cust-3 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[152]
# 	cust-3 ~ cust-8 ~ prod-6 ==> size: 4, diffs:[ 10 120 140]
# 	cust-3 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[214 297]
# 	cust-3 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[231]
# (3, 9) ->
#
# 	cust-3 ~ cust-9 ~ prod-0 ==> size: 2, diffs:[  7 148]
# 	cust-3 ~ cust-9 ~ prod-1 ==> size: 1, diffs:[100]
# 	cust-3 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[ 65 103]
# 	cust-3 ~ cust-9 ~ prod-4 ==> size: 2, diffs:[18 59]
# 	cust-3 ~ cust-9 ~ prod-6 ==> size: 4, diffs:[ 62 169 192]
# 	cust-3 ~ cust-9 ~ prod-9 ==> size: 1, diffs:[90]
# (3, 11) ->
#
# 	cust-3 ~ cust-11 ~ prod-0 ==> size: 1, diffs:[203]
# 	cust-3 ~ cust-11 ~ prod-2 ==> size: 1, diffs:[81]
# 	cust-3 ~ cust-11 ~ prod-4 ==> size: 2, diffs:[ 40 117]
# 	cust-3 ~ cust-11 ~ prod-7 ==> size: 3, diffs:[ 17  31 248]
# 	cust-3 ~ cust-11 ~ prod-9 ==> size: 1, diffs:[39]
# (3, 12) ->
#
# 	cust-3 ~ cust-12 ~ prod-1 ==> size: 3, diffs:[ 17  69 149]
# 	cust-3 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[ 82 193]
# 	cust-3 ~ cust-12 ~ prod-4 ==> size: 2, diffs:[164 241]
# 	cust-3 ~ cust-12 ~ prod-6 ==> size: 2, diffs:[ 12 142]
# 	cust-3 ~ cust-12 ~ prod-7 ==> size: 1, diffs:[8]
# 	cust-3 ~ cust-12 ~ prod-9 ==> size: 1, diffs:[18]
# (3, 15) ->
#
# 	cust-3 ~ cust-15 ~ prod-0 ==> size: 1, diffs:[176]
# 	cust-3 ~ cust-15 ~ prod-1 ==> size: 1, diffs:[179]
# 	cust-3 ~ cust-15 ~ prod-3 ==> size: 2, diffs:[ 88 343]
# 	cust-3 ~ cust-15 ~ prod-4 ==> size: 2, diffs:[ 83 160]
# 	cust-3 ~ cust-15 ~ prod-6 ==> size: 4, diffs:[ 26  43 104]
# 	cust-3 ~ cust-15 ~ prod-7 ==> size: 2, diffs:[  7 131]
# 	cust-3 ~ cust-15 ~ prod-9 ==> size: 1, diffs:[4]
# (3, 16) ->
#
# 	cust-3 ~ cust-16 ~ prod-0 ==> size: 1, diffs:[24]
# 	cust-3 ~ cust-16 ~ prod-6 ==> size: 6, diffs:[36 55 81]
# 	cust-3 ~ cust-16 ~ prod-7 ==> size: 2, diffs:[  8 303]
# 	cust-3 ~ cust-16 ~ prod-9 ==> size: 2, diffs:[26 38]
# (3, 20) ->
#
# 	cust-3 ~ cust-20 ~ prod-2 ==> size: 1, diffs:[29]
# 	cust-3 ~ cust-20 ~ prod-3 ==> size: 2, diffs:[  3 217]
# 	cust-3 ~ cust-20 ~ prod-4 ==> size: 4, diffs:[ 2 69 75]
# 	cust-3 ~ cust-20 ~ prod-6 ==> size: 2, diffs:[ 82 212]
# 	cust-3 ~ cust-20 ~ prod-7 ==> size: 1, diffs:[76]
# (3, 25) ->
#
# 	cust-3 ~ cust-25 ~ prod-0 ==> size: 3, diffs:[ 53 142 272]
# 	cust-3 ~ cust-25 ~ prod-2 ==> size: 1, diffs:[134]
# 	cust-3 ~ cust-25 ~ prod-4 ==> size: 4, diffs:[32 45 66]
# 	cust-3 ~ cust-25 ~ prod-7 ==> size: 1, diffs:[4]
# 	cust-3 ~ cust-25 ~ prod-9 ==> size: 2, diffs:[ 9 16]
# (4, 0) ->
#
# 	cust-4 ~ cust-0 ~ prod-1 ==> size: 4, diffs:[ 9 45 47]
# 	cust-4 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[222]
# 	cust-4 ~ cust-0 ~ prod-3 ==> size: 2, diffs:[ 45 153]
# 	cust-4 ~ cust-0 ~ prod-8 ==> size: 3, diffs:[ 3 40 66]
# (5, 0) ->
#
# 	cust-5 ~ cust-0 ~ prod-1 ==> size: 2, diffs:[ 97 189]
# 	cust-5 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[70]
# 	cust-5 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[142]
# 	cust-5 ~ cust-0 ~ prod-6 ==> size: 6, diffs:[ 11  43 109]
# 	cust-5 ~ cust-0 ~ prod-8 ==> size: 6, diffs:[ 16  53 122]
# (5, 1) ->
#
# 	cust-5 ~ cust-1 ~ prod-0 ==> size: 3, diffs:[117 159 188]
# 	cust-5 ~ cust-1 ~ prod-2 ==> size: 1, diffs:[137]
# 	cust-5 ~ cust-1 ~ prod-3 ==> size: 1, diffs:[152]
# 	cust-5 ~ cust-1 ~ prod-6 ==> size: 3, diffs:[ 84 215 269]
# 	cust-5 ~ cust-1 ~ prod-7 ==> size: 2, diffs:[ 72 268]
# 	cust-5 ~ cust-1 ~ prod-8 ==> size: 6, diffs:[26 55 61]
# (5, 2) ->
#
# 	cust-5 ~ cust-2 ~ prod-0 ==> size: 1, diffs:[238]
# 	cust-5 ~ cust-2 ~ prod-1 ==> size: 3, diffs:[ 12  72 111]
# 	cust-5 ~ cust-2 ~ prod-3 ==> size: 2, diffs:[30 93]
# 	cust-5 ~ cust-2 ~ prod-8 ==> size: 2, diffs:[ 22 262]
# 	cust-5 ~ cust-2 ~ prod-9 ==> size: 1, diffs:[260]
# (5, 3) ->
#
# 	cust-5 ~ cust-3 ~ prod-0 ==> size: 1, diffs:[198]
# 	cust-5 ~ cust-3 ~ prod-1 ==> size: 1, diffs:[58]
# 	cust-5 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[97]
# 	cust-5 ~ cust-3 ~ prod-3 ==> size: 1, diffs:[328]
# 	cust-5 ~ cust-3 ~ prod-6 ==> size: 6, diffs:[59 71 72]
# 	cust-5 ~ cust-3 ~ prod-7 ==> size: 2, diffs:[ 79 275]
# 	cust-5 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[233]
# (5, 9) ->
#
# 	cust-5 ~ cust-9 ~ prod-0 ==> size: 2, diffs:[ 50 191]
# 	cust-5 ~ cust-9 ~ prod-1 ==> size: 1, diffs:[42]
# 	cust-5 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[162 200]
# 	cust-5 ~ cust-9 ~ prod-6 ==> size: 6, diffs:[10 43 64]
# 	cust-5 ~ cust-9 ~ prod-8 ==> size: 4, diffs:[ 34 127 157]
# 	cust-5 ~ cust-9 ~ prod-9 ==> size: 1, diffs:[143]
# (5, 11) ->
#
# 	cust-5 ~ cust-11 ~ prod-0 ==> size: 1, diffs:[5]
# 	cust-5 ~ cust-11 ~ prod-2 ==> size: 1, diffs:[16]
# 	cust-5 ~ cust-11 ~ prod-7 ==> size: 6, diffs:[ 27  96 110]
# 	cust-5 ~ cust-11 ~ prod-8 ==> size: 2, diffs:[118 166]
# 	cust-5 ~ cust-11 ~ prod-9 ==> size: 1, diffs:[272]
# (5, 12) ->
#
# 	cust-5 ~ cust-12 ~ prod-1 ==> size: 3, diffs:[ 11  41 207]
# 	cust-5 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[135 246]
# 	cust-5 ~ cust-12 ~ prod-6 ==> size: 3, diffs:[ 83 214 268]
# 	cust-5 ~ cust-12 ~ prod-7 ==> size: 2, diffs:[ 87 283]
# 	cust-5 ~ cust-12 ~ prod-8 ==> size: 2, diffs:[ 36 248]
# 	cust-5 ~ cust-12 ~ prod-9 ==> size: 1, diffs:[215]
# (5, 13) ->
#
# 	cust-5 ~ cust-13 ~ prod-0 ==> size: 2, diffs:[ 79 148]
# 	cust-5 ~ cust-13 ~ prod-2 ==> size: 1, diffs:[101]
# 	cust-5 ~ cust-13 ~ prod-3 ==> size: 2, diffs:[ 79 323]
# 	cust-5 ~ cust-13 ~ prod-6 ==> size: 3, diffs:[ 63 194 248]
# 	cust-5 ~ cust-13 ~ prod-7 ==> size: 2, diffs:[ 22 174]
# 	cust-5 ~ cust-13 ~ prod-8 ==> size: 2, diffs:[ 18 266]
# 	cust-5 ~ cust-13 ~ prod-9 ==> size: 1, diffs:[288]
# (5, 14) ->
#
# 	cust-5 ~ cust-14 ~ prod-1 ==> size: 2, diffs:[ 61 127]
# 	cust-5 ~ cust-14 ~ prod-2 ==> size: 1, diffs:[50]
# 	cust-5 ~ cust-14 ~ prod-6 ==> size: 3, diffs:[ 19  73 204]
# 	cust-5 ~ cust-14 ~ prod-8 ==> size: 4, diffs:[  1   6 285]
# 	cust-5 ~ cust-14 ~ prod-9 ==> size: 2, diffs:[ 55 157]
# (5, 15) ->
#
# 	cust-5 ~ cust-15 ~ prod-0 ==> size: 1, diffs:[22]
# 	cust-5 ~ cust-15 ~ prod-1 ==> size: 1, diffs:[121]
# 	cust-5 ~ cust-15 ~ prod-3 ==> size: 2, diffs:[ 15 240]
# 	cust-5 ~ cust-15 ~ prod-6 ==> size: 6, diffs:[29 33 83]
# 	cust-5 ~ cust-15 ~ prod-7 ==> size: 4, diffs:[ 52  86 144]
# 	cust-5 ~ cust-15 ~ prod-9 ==> size: 1, diffs:[237]
# (5, 18) ->
#
# 	cust-5 ~ cust-18 ~ prod-0 ==> size: 1, diffs:[224]
# 	cust-5 ~ cust-18 ~ prod-1 ==> size: 4, diffs:[ 40  79 121]
# 	cust-5 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[63]
# 	cust-5 ~ cust-18 ~ prod-7 ==> size: 2, diffs:[  2 198]
# 	cust-5 ~ cust-18 ~ prod-8 ==> size: 6, diffs:[ 54  75 126]
# 	cust-5 ~ cust-18 ~ prod-9 ==> size: 1, diffs:[56]
# (5, 21) ->
#
# 	cust-5 ~ cust-21 ~ prod-1 ==> size: 1, diffs:[99]
# 	cust-5 ~ cust-21 ~ prod-2 ==> size: 1, diffs:[39]
# 	cust-5 ~ cust-21 ~ prod-6 ==> size: 6, diffs:[ 18  20 113]
# 	cust-5 ~ cust-21 ~ prod-9 ==> size: 1, diffs:[7]
# (5, 24) ->
#
# 	cust-5 ~ cust-24 ~ prod-0 ==> size: 1, diffs:[51]
# 	cust-5 ~ cust-24 ~ prod-1 ==> size: 1, diffs:[209]
# 	cust-5 ~ cust-24 ~ prod-3 ==> size: 1, diffs:[261]
# 	cust-5 ~ cust-24 ~ prod-6 ==> size: 3, diffs:[ 62  69 116]
# 	cust-5 ~ cust-24 ~ prod-8 ==> size: 4, diffs:[106 131 153]
# 	cust-5 ~ cust-24 ~ prod-9 ==> size: 2, diffs:[ 8 45]
# (5, 25) ->
#
# 	cust-5 ~ cust-25 ~ prod-0 ==> size: 3, diffs:[ 56  74 251]
# 	cust-5 ~ cust-25 ~ prod-2 ==> size: 1, diffs:[37]
# 	cust-5 ~ cust-25 ~ prod-7 ==> size: 2, diffs:[ 75 271]
# 	cust-5 ~ cust-25 ~ prod-9 ==> size: 2, diffs:[242 249]
# (5, 27) ->
#
# 	cust-5 ~ cust-27 ~ prod-1 ==> size: 1, diffs:[82]
# 	cust-5 ~ cust-27 ~ prod-7 ==> size: 2, diffs:[ 57 253]
# 	cust-5 ~ cust-27 ~ prod-8 ==> size: 2, diffs:[108 176]
# 	cust-5 ~ cust-27 ~ prod-9 ==> size: 3, diffs:[ 35 199 291]
# (5, 33) ->
#
# 	cust-5 ~ cust-33 ~ prod-1 ==> size: 1, diffs:[40]
# 	cust-5 ~ cust-33 ~ prod-6 ==> size: 3, diffs:[  2  56 187]
# 	cust-5 ~ cust-33 ~ prod-7 ==> size: 4, diffs:[ 43  95 101]
# 	cust-5 ~ cust-33 ~ prod-9 ==> size: 3, diffs:[ 61 227 254]
# (6, 0) ->
#
# 	cust-6 ~ cust-0 ~ prod-1 ==> size: 4, diffs:[ 8 29 63]
# 	cust-6 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[22]
# 	cust-6 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[206]
# 	cust-6 ~ cust-0 ~ prod-8 ==> size: 6, diffs:[ 69 138 149]
# (6, 1) ->
#
# 	cust-6 ~ cust-1 ~ prod-3 ==> size: 1, diffs:[32]
# 	cust-6 ~ cust-1 ~ prod-4 ==> size: 1, diffs:[141]
# 	cust-6 ~ cust-1 ~ prod-5 ==> size: 1, diffs:[60]
# 	cust-6 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[99]
# 	cust-6 ~ cust-1 ~ prod-8 ==> size: 6, diffs:[136 165 216]
# (6, 2) ->
#
# 	cust-6 ~ cust-2 ~ prod-1 ==> size: 6, diffs:[15 54 86]
# 	cust-6 ~ cust-2 ~ prod-3 ==> size: 2, diffs:[27 90]
# 	cust-6 ~ cust-2 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-6 ~ cust-2 ~ prod-5 ==> size: 2, diffs:[115 215]
# 	cust-6 ~ cust-2 ~ prod-8 ==> size: 2, diffs:[ 9 71]
# (6, 3) ->
#
# 	cust-6 ~ cust-3 ~ prod-1 ==> size: 2, diffs:[ 68 139]
# 	cust-6 ~ cust-3 ~ prod-3 ==> size: 1, diffs:[208]
# 	cust-6 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[150 227]
# 	cust-6 ~ cust-3 ~ prod-7 ==> size: 1, diffs:[106]
# (6, 7) ->
#
# 	cust-6 ~ cust-7 ~ prod-1 ==> size: 4, diffs:[16 87 92]
# 	cust-6 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[ 55 134]
# 	cust-6 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[14]
# 	cust-6 ~ cust-7 ~ prod-7 ==> size: 1, diffs:[46]
# (6, 8) ->
#
# 	cust-6 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[108 191]
# 	cust-6 ~ cust-8 ~ prod-8 ==> size: 2, diffs:[ 27 107]
# (6, 11) ->
#
# 	cust-6 ~ cust-11 ~ prod-4 ==> size: 1, diffs:[110]
# 	cust-6 ~ cust-11 ~ prod-5 ==> size: 1, diffs:[198]
# 	cust-6 ~ cust-11 ~ prod-7 ==> size: 3, diffs:[123 137 142]
# 	cust-6 ~ cust-11 ~ prod-8 ==> size: 2, diffs:[ 73 153]
# (6, 12) ->
#
# 	cust-6 ~ cust-12 ~ prod-1 ==> size: 6, diffs:[10 81 85]
# 	cust-6 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[ 15 126]
# 	cust-6 ~ cust-12 ~ prod-4 ==> size: 1, diffs:[14]
# 	cust-6 ~ cust-12 ~ prod-5 ==> size: 1, diffs:[148]
# 	cust-6 ~ cust-12 ~ prod-7 ==> size: 1, diffs:[114]
# 	cust-6 ~ cust-12 ~ prod-8 ==> size: 2, diffs:[155 235]
# (6, 14) ->
#
# 	cust-6 ~ cust-14 ~ prod-1 ==> size: 4, diffs:[187 253 258]
# 	cust-6 ~ cust-14 ~ prod-4 ==> size: 1, diffs:[8]
# 	cust-6 ~ cust-14 ~ prod-5 ==> size: 2, diffs:[121 143]
# 	cust-6 ~ cust-14 ~ prod-8 ==> size: 4, diffs:[ 19  99 192]
# (6, 17) ->
#
# 	cust-6 ~ cust-17 ~ prod-3 ==> size: 2, diffs:[ 80 154]
# 	cust-6 ~ cust-17 ~ prod-8 ==> size: 2, diffs:[ 26 106]
# (6, 19) ->
#
# 	cust-6 ~ cust-19 ~ prod-1 ==> size: 2, diffs:[193 264]
# 	cust-6 ~ cust-19 ~ prod-4 ==> size: 1, diffs:[20]
# 	cust-6 ~ cust-19 ~ prod-5 ==> size: 1, diffs:[232]
# 	cust-6 ~ cust-19 ~ prod-7 ==> size: 3, diffs:[ 58  79 156]
# 	cust-6 ~ cust-19 ~ prod-8 ==> size: 4, diffs:[12 63 92]
# (6, 20) ->
#
# 	cust-6 ~ cust-20 ~ prod-3 ==> size: 2, diffs:[  9 205]
# 	cust-6 ~ cust-20 ~ prod-4 ==> size: 2, diffs:[ 81 152]
# 	cust-6 ~ cust-20 ~ prod-7 ==> size: 1, diffs:[30]
# 	cust-6 ~ cust-20 ~ prod-8 ==> size: 4, diffs:[ 42 122 232]
# (6, 22) ->
#
# 	cust-6 ~ cust-22 ~ prod-1 ==> size: 2, diffs:[ 59 130]
# 	cust-6 ~ cust-22 ~ prod-3 ==> size: 1, diffs:[48]
# 	cust-6 ~ cust-22 ~ prod-4 ==> size: 2, diffs:[ 23 256]
# 	cust-6 ~ cust-22 ~ prod-5 ==> size: 1, diffs:[45]
# 	cust-6 ~ cust-22 ~ prod-8 ==> size: 4, diffs:[  9  89 161]
# (6, 23) ->
#
# 	cust-6 ~ cust-23 ~ prod-1 ==> size: 2, diffs:[156 227]
# 	cust-6 ~ cust-23 ~ prod-3 ==> size: 1, diffs:[39]
# 	cust-6 ~ cust-23 ~ prod-5 ==> size: 1, diffs:[80]
# 	cust-6 ~ cust-23 ~ prod-7 ==> size: 1, diffs:[31]
# (6, 25) ->
#
# 	cust-6 ~ cust-25 ~ prod-4 ==> size: 2, diffs:[ 84 182]
# 	cust-6 ~ cust-25 ~ prod-5 ==> size: 2, diffs:[ 53 203]
# 	cust-6 ~ cust-25 ~ prod-7 ==> size: 1, diffs:[102]
# (6, 26) ->
#
# 	cust-6 ~ cust-26 ~ prod-1 ==> size: 2, diffs:[ 73 144]
# 	cust-6 ~ cust-26 ~ prod-3 ==> size: 1, diffs:[169]
# 	cust-6 ~ cust-26 ~ prod-7 ==> size: 1, diffs:[97]
# 	cust-6 ~ cust-26 ~ prod-8 ==> size: 2, diffs:[ 74 154]
# (6, 27) ->
#
# 	cust-6 ~ cust-27 ~ prod-1 ==> size: 2, diffs:[208 279]
# 	cust-6 ~ cust-27 ~ prod-4 ==> size: 1, diffs:[288]
# 	cust-6 ~ cust-27 ~ prod-5 ==> size: 1, diffs:[146]
# 	cust-6 ~ cust-27 ~ prod-7 ==> size: 1, diffs:[84]
# 	cust-6 ~ cust-27 ~ prod-8 ==> size: 2, diffs:[ 83 163]
# (7, 0) ->
#
# 	cust-7 ~ cust-0 ~ prod-1 ==> size: 4, diffs:[13 63 79]
# 	cust-7 ~ cust-0 ~ prod-3 ==> size: 2, diffs:[ 77 112]
# (7, 1) ->
#
# 	cust-7 ~ cust-1 ~ prod-0 ==> size: 6, diffs:[ 6 36 65]
# 	cust-7 ~ cust-1 ~ prod-3 ==> size: 2, diffs:[ 87 102]
# 	cust-7 ~ cust-1 ~ prod-5 ==> size: 1, diffs:[74]
# 	cust-7 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[145]
# (7, 3) ->
#
# 	cust-7 ~ cust-3 ~ prod-0 ==> size: 2, diffs:[ 75 293]
# 	cust-7 ~ cust-3 ~ prod-1 ==> size: 2, diffs:[24 52]
# 	cust-7 ~ cust-3 ~ prod-3 ==> size: 2, diffs:[ 74 263]
# 	cust-7 ~ cust-3 ~ prod-7 ==> size: 1, diffs:[152]
# 	cust-7 ~ cust-3 ~ prod-9 ==> size: 2, diffs:[ 10 262]
# (7, 6) ->
#
# 	cust-7 ~ cust-6 ~ prod-1 ==> size: 4, diffs:[16 87 92]
# 	cust-7 ~ cust-6 ~ prod-3 ==> size: 2, diffs:[ 55 134]
# 	cust-7 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[14]
# 	cust-7 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[46]
# (7, 9) ->
#
# 	cust-7 ~ cust-9 ~ prod-0 ==> size: 4, diffs:[ 68  73 145]
# 	cust-7 ~ cust-9 ~ prod-1 ==> size: 2, diffs:[ 76 152]
# 	cust-7 ~ cust-9 ~ prod-9 ==> size: 2, diffs:[100 172]
# (7, 11) ->
#
# 	cust-7 ~ cust-11 ~ prod-0 ==> size: 2, diffs:[ 90 128]
# 	cust-7 ~ cust-11 ~ prod-5 ==> size: 1, diffs:[212]
# 	cust-7 ~ cust-11 ~ prod-7 ==> size: 3, diffs:[ 96 169 183]
# 	cust-7 ~ cust-11 ~ prod-9 ==> size: 2, diffs:[ 29 301]
# (7, 14) ->
#
# 	cust-7 ~ cust-14 ~ prod-1 ==> size: 4, diffs:[ 95 161 171]
# 	cust-7 ~ cust-14 ~ prod-5 ==> size: 2, diffs:[135 157]
# 	cust-7 ~ cust-14 ~ prod-9 ==> size: 4, diffs:[ 84  86 186]
# (7, 16) ->
#
# 	cust-7 ~ cust-16 ~ prod-0 ==> size: 2, diffs:[ 51 269]
# 	cust-7 ~ cust-16 ~ prod-5 ==> size: 1, diffs:[65]
# 	cust-7 ~ cust-16 ~ prod-7 ==> size: 2, diffs:[144 151]
# 	cust-7 ~ cust-16 ~ prod-9 ==> size: 4, diffs:[ 16  48 224]
# (7, 17) ->
#
# 	cust-7 ~ cust-17 ~ prod-0 ==> size: 4, diffs:[ 73 103 115]
# 	cust-7 ~ cust-17 ~ prod-3 ==> size: 4, diffs:[ 20  25 209]
# 	cust-7 ~ cust-17 ~ prod-9 ==> size: 2, diffs:[ 32 304]
# (7, 26) ->
#
# 	cust-7 ~ cust-26 ~ prod-0 ==> size: 2, diffs:[  3 215]
# 	cust-7 ~ cust-26 ~ prod-1 ==> size: 2, diffs:[19 57]
# 	cust-7 ~ cust-26 ~ prod-3 ==> size: 2, diffs:[ 35 224]
# 	cust-7 ~ cust-26 ~ prod-7 ==> size: 1, diffs:[51]
# 	cust-7 ~ cust-26 ~ prod-9 ==> size: 2, diffs:[ 68 204]
# (7, 31) ->
#
# 	cust-7 ~ cust-31 ~ prod-3 ==> size: 2, diffs:[  1 188]
# 	cust-7 ~ cust-31 ~ prod-5 ==> size: 1, diffs:[66]
# 	cust-7 ~ cust-31 ~ prod-7 ==> size: 2, diffs:[30 78]
# (7, 34) ->
#
# 	cust-7 ~ cust-34 ~ prod-0 ==> size: 8, diffs:[ 18  53 104]
# 	cust-7 ~ cust-34 ~ prod-5 ==> size: 1, diffs:[206]
# 	cust-7 ~ cust-34 ~ prod-7 ==> size: 2, diffs:[27 82]
# 	cust-7 ~ cust-34 ~ prod-9 ==> size: 4, diffs:[  9  36 281]
# (8, 0) ->
#
# 	cust-8 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[125]
# 	cust-8 ~ cust-0 ~ prod-6 ==> size: 4, diffs:[ 25  48 235]
# 	cust-8 ~ cust-0 ~ prod-8 ==> size: 3, diffs:[176 245 282]
# (8, 2) ->
#
# 	cust-8 ~ cust-2 ~ prod-0 ==> size: 2, diffs:[113 217]
# 	cust-8 ~ cust-2 ~ prod-8 ==> size: 1, diffs:[36]
# 	cust-8 ~ cust-2 ~ prod-9 ==> size: 1, diffs:[258]
# (8, 3) ->
#
# 	cust-8 ~ cust-3 ~ prod-0 ==> size: 2, diffs:[ 73 177]
# 	cust-8 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[152]
# 	cust-8 ~ cust-3 ~ prod-6 ==> size: 4, diffs:[ 10 120 140]
# 	cust-8 ~ cust-3 ~ prod-7 ==> size: 2, diffs:[214 297]
# 	cust-8 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[231]
# (8, 6) ->
#
# 	cust-8 ~ cust-6 ~ prod-7 ==> size: 2, diffs:[108 191]
# 	cust-8 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 27 107]
# (8, 9) ->
#
# 	cust-8 ~ cust-9 ~ prod-0 ==> size: 4, diffs:[29 66 75]
# 	cust-8 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[217 255]
# 	cust-8 ~ cust-9 ~ prod-6 ==> size: 4, diffs:[ 29  78 182]
# 	cust-8 ~ cust-9 ~ prod-8 ==> size: 2, diffs:[ 48 141]
# 	cust-8 ~ cust-9 ~ prod-9 ==> size: 1, diffs:[141]
# (8, 10) ->
#
# 	cust-8 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[ 72 178]
# 	cust-8 ~ cust-10 ~ prod-6 ==> size: 2, diffs:[ 29 289]
# 	cust-8 ~ cust-10 ~ prod-7 ==> size: 2, diffs:[241 324]
# 	cust-8 ~ cust-10 ~ prod-9 ==> size: 1, diffs:[62]
# (8, 13) ->
#
# 	cust-8 ~ cust-13 ~ prod-0 ==> size: 4, diffs:[23 46 58]
# 	cust-8 ~ cust-13 ~ prod-2 ==> size: 1, diffs:[46]
# 	cust-8 ~ cust-13 ~ prod-6 ==> size: 2, diffs:[  2 262]
# 	cust-8 ~ cust-13 ~ prod-7 ==> size: 2, diffs:[113 196]
# 	cust-8 ~ cust-13 ~ prod-8 ==> size: 1, diffs:[32]
# 	cust-8 ~ cust-13 ~ prod-9 ==> size: 1, diffs:[286]
# (8, 17) ->
#
# 	cust-8 ~ cust-17 ~ prod-0 ==> size: 4, diffs:[  1  71 105]
# 	cust-8 ~ cust-17 ~ prod-2 ==> size: 2, diffs:[15 98]
# 	cust-8 ~ cust-17 ~ prod-6 ==> size: 4, diffs:[ 51  67 193]
# 	cust-8 ~ cust-17 ~ prod-8 ==> size: 1, diffs:[133]
# 	cust-8 ~ cust-17 ~ prod-9 ==> size: 1, diffs:[63]
# (8, 18) ->
#
# 	cust-8 ~ cust-18 ~ prod-0 ==> size: 2, diffs:[ 99 203]
# 	cust-8 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[118]
# 	cust-8 ~ cust-18 ~ prod-7 ==> size: 2, diffs:[20 63]
# 	cust-8 ~ cust-18 ~ prod-8 ==> size: 3, diffs:[ 89 140 244]
# 	cust-8 ~ cust-18 ~ prod-9 ==> size: 1, diffs:[58]
# (8, 19) ->
#
# 	cust-8 ~ cust-19 ~ prod-2 ==> size: 1, diffs:[29]
# 	cust-8 ~ cust-19 ~ prod-6 ==> size: 2, diffs:[ 67 327]
# 	cust-8 ~ cust-19 ~ prod-7 ==> size: 6, diffs:[ 29 112 166]
# 	cust-8 ~ cust-19 ~ prod-8 ==> size: 2, diffs:[119 170]
# 	cust-8 ~ cust-19 ~ prod-9 ==> size: 2, diffs:[139 186]
# (8, 20) ->
#
# 	cust-8 ~ cust-20 ~ prod-2 ==> size: 1, diffs:[181]
# 	cust-8 ~ cust-20 ~ prod-6 ==> size: 2, diffs:[ 58 202]
# 	cust-8 ~ cust-20 ~ prod-7 ==> size: 2, diffs:[138 221]
# 	cust-8 ~ cust-20 ~ prod-8 ==> size: 2, diffs:[149 339]
# (8, 22) ->
#
# 	cust-8 ~ cust-22 ~ prod-2 ==> size: 1, diffs:[90]
# 	cust-8 ~ cust-22 ~ prod-6 ==> size: 2, diffs:[ 16 244]
# 	cust-8 ~ cust-22 ~ prod-8 ==> size: 2, diffs:[116 268]
# 	cust-8 ~ cust-22 ~ prod-9 ==> size: 1, diffs:[281]
# (8, 26) ->
#
# 	cust-8 ~ cust-26 ~ prod-0 ==> size: 2, diffs:[113 217]
# 	cust-8 ~ cust-26 ~ prod-2 ==> size: 4, diffs:[ 83 131 194]
# 	cust-8 ~ cust-26 ~ prod-6 ==> size: 2, diffs:[ 45 215]
# 	cust-8 ~ cust-26 ~ prod-7 ==> size: 2, diffs:[11 94]
# 	cust-8 ~ cust-26 ~ prod-8 ==> size: 1, diffs:[181]
# 	cust-8 ~ cust-26 ~ prod-9 ==> size: 1, diffs:[37]
# (8, 28) ->
#
# 	cust-8 ~ cust-28 ~ prod-0 ==> size: 2, diffs:[ 10 114]
# 	cust-8 ~ cust-28 ~ prod-2 ==> size: 1, diffs:[109]
# 	cust-8 ~ cust-28 ~ prod-6 ==> size: 2, diffs:[ 10 250]
# 	cust-8 ~ cust-28 ~ prod-7 ==> size: 2, diffs:[ 3 86]
# (8, 29) ->
#
# 	cust-8 ~ cust-29 ~ prod-0 ==> size: 2, diffs:[ 31 135]
# 	cust-8 ~ cust-29 ~ prod-2 ==> size: 1, diffs:[115]
# 	cust-8 ~ cust-29 ~ prod-6 ==> size: 2, diffs:[107 153]
# 	cust-8 ~ cust-29 ~ prod-8 ==> size: 1, diffs:[44]
# (8, 31) ->
#
# 	cust-8 ~ cust-31 ~ prod-2 ==> size: 1, diffs:[81]
# 	cust-8 ~ cust-31 ~ prod-6 ==> size: 6, diffs:[13 64 75]
# 	cust-8 ~ cust-31 ~ prod-7 ==> size: 4, diffs:[16 67 92]
# 	cust-8 ~ cust-31 ~ prod-8 ==> size: 2, diffs:[22 55]
# (8, 33) ->
#
# 	cust-8 ~ cust-33 ~ prod-6 ==> size: 2, diffs:[ 12 248]
# 	cust-8 ~ cust-33 ~ prod-7 ==> size: 4, diffs:[ 40 123 178]
# 	cust-8 ~ cust-33 ~ prod-9 ==> size: 3, diffs:[ 59 225 252]
# (9, 3) ->
#
# 	cust-9 ~ cust-3 ~ prod-0 ==> size: 2, diffs:[  7 148]
# 	cust-9 ~ cust-3 ~ prod-1 ==> size: 1, diffs:[100]
# 	cust-9 ~ cust-3 ~ prod-2 ==> size: 2, diffs:[ 65 103]
# 	cust-9 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[18 59]
# 	cust-9 ~ cust-3 ~ prod-6 ==> size: 4, diffs:[ 62 169 192]
# 	cust-9 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[90]
# (9, 5) ->
#
# 	cust-9 ~ cust-5 ~ prod-0 ==> size: 2, diffs:[ 50 191]
# 	cust-9 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[42]
# 	cust-9 ~ cust-5 ~ prod-2 ==> size: 2, diffs:[162 200]
# 	cust-9 ~ cust-5 ~ prod-6 ==> size: 6, diffs:[10 43 64]
# 	cust-9 ~ cust-5 ~ prod-8 ==> size: 4, diffs:[ 34 127 157]
# 	cust-9 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[143]
# (9, 7) ->
#
# 	cust-9 ~ cust-7 ~ prod-0 ==> size: 4, diffs:[ 68  73 145]
# 	cust-9 ~ cust-7 ~ prod-1 ==> size: 2, diffs:[ 76 152]
# 	cust-9 ~ cust-7 ~ prod-9 ==> size: 2, diffs:[100 172]
# (9, 8) ->
#
# 	cust-9 ~ cust-8 ~ prod-0 ==> size: 4, diffs:[29 66 75]
# 	cust-9 ~ cust-8 ~ prod-2 ==> size: 2, diffs:[217 255]
# 	cust-9 ~ cust-8 ~ prod-6 ==> size: 4, diffs:[ 29  78 182]
# 	cust-9 ~ cust-8 ~ prod-8 ==> size: 2, diffs:[ 48 141]
# 	cust-9 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[141]
# (9, 10) ->
#
# 	cust-9 ~ cust-10 ~ prod-2 ==> size: 4, diffs:[ 39  77 145]
# 	cust-9 ~ cust-10 ~ prod-4 ==> size: 3, diffs:[ 20  98 129]
# 	cust-9 ~ cust-10 ~ prod-6 ==> size: 2, diffs:[211 318]
# 	cust-9 ~ cust-10 ~ prod-9 ==> size: 1, diffs:[79]
# (9, 16) ->
#
# 	cust-9 ~ cust-16 ~ prod-0 ==> size: 2, diffs:[ 17 124]
# 	cust-9 ~ cust-16 ~ prod-6 ==> size: 6, diffs:[ 7 19 88]
# 	cust-9 ~ cust-16 ~ prod-8 ==> size: 6, diffs:[ 16  35 109]
# 	cust-9 ~ cust-16 ~ prod-9 ==> size: 2, diffs:[ 52 116]
# (9, 22) ->
#
# 	cust-9 ~ cust-22 ~ prod-1 ==> size: 1, diffs:[109]
# 	cust-9 ~ cust-22 ~ prod-2 ==> size: 2, diffs:[127 165]
# 	cust-9 ~ cust-22 ~ prod-4 ==> size: 2, diffs:[ 88 145]
# 	cust-9 ~ cust-22 ~ prod-6 ==> size: 2, diffs:[166 273]
# 	cust-9 ~ cust-22 ~ prod-8 ==> size: 4, diffs:[ 25  68 127]
# 	cust-9 ~ cust-22 ~ prod-9 ==> size: 1, diffs:[140]
# (9, 23) ->
#
# 	cust-9 ~ cust-23 ~ prod-0 ==> size: 4, diffs:[ 39  99 180]
# 	cust-9 ~ cust-23 ~ prod-1 ==> size: 1, diffs:[12]
# 	cust-9 ~ cust-23 ~ prod-2 ==> size: 2, diffs:[192 230]
# 	cust-9 ~ cust-23 ~ prod-9 ==> size: 2, diffs:[ 87 123]
# (9, 29) ->
#
# 	cust-9 ~ cust-29 ~ prod-0 ==> size: 2, diffs:[ 35 106]
# 	cust-9 ~ cust-29 ~ prod-1 ==> size: 1, diffs:[39]
# 	cust-9 ~ cust-29 ~ prod-2 ==> size: 2, diffs:[102 140]
# 	cust-9 ~ cust-29 ~ prod-4 ==> size: 3, diffs:[ 45 135 185]
# 	cust-9 ~ cust-29 ~ prod-6 ==> size: 2, diffs:[ 75 182]
# 	cust-9 ~ cust-29 ~ prod-8 ==> size: 2, diffs:[ 4 97]
# (9, 31) ->
#
# 	cust-9 ~ cust-31 ~ prod-2 ==> size: 2, diffs:[136 174]
# 	cust-9 ~ cust-31 ~ prod-4 ==> size: 2, diffs:[ 26 107]
# 	cust-9 ~ cust-31 ~ prod-6 ==> size: 6, diffs:[  3 104 195]
# 	cust-9 ~ cust-31 ~ prod-8 ==> size: 4, diffs:[ 7 26 86]
# (9, 32) ->
#
# 	cust-9 ~ cust-32 ~ prod-1 ==> size: 2, diffs:[ 35 111]
# 	cust-9 ~ cust-32 ~ prod-4 ==> size: 1, diffs:[179]
# 	cust-9 ~ cust-32 ~ prod-6 ==> size: 4, diffs:[ 25  82 148]
# 	cust-9 ~ cust-32 ~ prod-8 ==> size: 4, diffs:[ 35  58 184]
# (10, 0) ->
#
# 	cust-10 ~ cust-0 ~ prod-2 ==> size: 2, diffs:[53 53]
# 	cust-10 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[95]
# 	cust-10 ~ cust-0 ~ prod-4 ==> size: 3, diffs:[58 60 91]
# 	cust-10 ~ cust-0 ~ prod-6 ==> size: 2, diffs:[ 19 264]
# (10, 1) ->
#
# 	cust-10 ~ cust-1 ~ prod-2 ==> size: 2, diffs:[154 260]
# 	cust-10 ~ cust-1 ~ prod-3 ==> size: 1, diffs:[85]
# 	cust-10 ~ cust-1 ~ prod-4 ==> size: 3, diffs:[  7 125 156]
# 	cust-10 ~ cust-1 ~ prod-5 ==> size: 2, diffs:[ 54 117]
# 	cust-10 ~ cust-1 ~ prod-6 ==> size: 1, diffs:[6]
# 	cust-10 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[34]
# (10, 8) ->
#
# 	cust-10 ~ cust-8 ~ prod-2 ==> size: 2, diffs:[ 72 178]
# 	cust-10 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 29 289]
# 	cust-10 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[241 324]
# 	cust-10 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[62]
# (10, 9) ->
#
# 	cust-10 ~ cust-9 ~ prod-2 ==> size: 4, diffs:[ 39  77 145]
# 	cust-10 ~ cust-9 ~ prod-4 ==> size: 3, diffs:[ 20  98 129]
# 	cust-10 ~ cust-9 ~ prod-6 ==> size: 2, diffs:[211 318]
# 	cust-10 ~ cust-9 ~ prod-9 ==> size: 1, diffs:[79]
# (10, 13) ->
#
# 	cust-10 ~ cust-13 ~ prod-2 ==> size: 2, diffs:[118 224]
# 	cust-10 ~ cust-13 ~ prod-3 ==> size: 2, diffs:[ 86 158]
# 	cust-10 ~ cust-13 ~ prod-4 ==> size: 6, diffs:[ 10  40 108]
# 	cust-10 ~ cust-13 ~ prod-5 ==> size: 2, diffs:[23 40]
# 	cust-10 ~ cust-13 ~ prod-6 ==> size: 1, diffs:[27]
# 	cust-10 ~ cust-13 ~ prod-7 ==> size: 1, diffs:[128]
# 	cust-10 ~ cust-13 ~ prod-9 ==> size: 1, diffs:[224]
# (10, 15) ->
#
# 	cust-10 ~ cust-15 ~ prod-3 ==> size: 2, diffs:[  3 252]
# 	cust-10 ~ cust-15 ~ prod-4 ==> size: 3, diffs:[ 81 199 230]
# 	cust-10 ~ cust-15 ~ prod-6 ==> size: 2, diffs:[123 192]
# 	cust-10 ~ cust-15 ~ prod-7 ==> size: 2, diffs:[ 20 158]
# 	cust-10 ~ cust-15 ~ prod-9 ==> size: 1, diffs:[173]
# (10, 18) ->
#
# 	cust-10 ~ cust-18 ~ prod-2 ==> size: 2, diffs:[46 60]
# 	cust-10 ~ cust-18 ~ prod-5 ==> size: 2, diffs:[ 62 125]
# 	cust-10 ~ cust-18 ~ prod-7 ==> size: 1, diffs:[304]
# 	cust-10 ~ cust-18 ~ prod-9 ==> size: 1, diffs:[120]
# (10, 19) ->
#
# 	cust-10 ~ cust-19 ~ prod-2 ==> size: 2, diffs:[101 207]
# 	cust-10 ~ cust-19 ~ prod-4 ==> size: 3, diffs:[128 246 277]
# 	cust-10 ~ cust-19 ~ prod-5 ==> size: 2, diffs:[226 289]
# 	cust-10 ~ cust-19 ~ prod-6 ==> size: 1, diffs:[38]
# 	cust-10 ~ cust-19 ~ prod-7 ==> size: 3, diffs:[ 23  75 212]
# 	cust-10 ~ cust-19 ~ prod-9 ==> size: 2, diffs:[ 77 124]
# (11, 3) ->
#
# 	cust-11 ~ cust-3 ~ prod-0 ==> size: 1, diffs:[203]
# 	cust-11 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[81]
# 	cust-11 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[ 40 117]
# 	cust-11 ~ cust-3 ~ prod-7 ==> size: 3, diffs:[ 17  31 248]
# 	cust-11 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[39]
# (11, 5) ->
#
# 	cust-11 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[5]
# 	cust-11 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[16]
# 	cust-11 ~ cust-5 ~ prod-7 ==> size: 6, diffs:[ 27  96 110]
# 	cust-11 ~ cust-5 ~ prod-8 ==> size: 2, diffs:[118 166]
# 	cust-11 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[272]
# (11, 6) ->
#
# 	cust-11 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[110]
# 	cust-11 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[198]
# 	cust-11 ~ cust-6 ~ prod-7 ==> size: 3, diffs:[123 137 142]
# 	cust-11 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 73 153]
# (11, 7) ->
#
# 	cust-11 ~ cust-7 ~ prod-0 ==> size: 2, diffs:[ 90 128]
# 	cust-11 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[212]
# 	cust-11 ~ cust-7 ~ prod-7 ==> size: 3, diffs:[ 96 169 183]
# 	cust-11 ~ cust-7 ~ prod-9 ==> size: 2, diffs:[ 29 301]
# (11, 15) ->
#
# 	cust-11 ~ cust-15 ~ prod-0 ==> size: 1, diffs:[27]
# 	cust-11 ~ cust-15 ~ prod-4 ==> size: 1, diffs:[43]
# 	cust-11 ~ cust-15 ~ prod-7 ==> size: 6, diffs:[ 10  24 117]
# 	cust-11 ~ cust-15 ~ prod-9 ==> size: 1, diffs:[35]
# (12, 1) ->
#
# 	cust-12 ~ cust-1 ~ prod-3 ==> size: 2, diffs:[17 94]
# 	cust-12 ~ cust-1 ~ prod-4 ==> size: 1, diffs:[155]
# 	cust-12 ~ cust-1 ~ prod-5 ==> size: 1, diffs:[88]
# 	cust-12 ~ cust-1 ~ prod-6 ==> size: 1, diffs:[1]
# 	cust-12 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[15]
# 	cust-12 ~ cust-1 ~ prod-8 ==> size: 3, diffs:[10 19 97]
# (12, 3) ->
#
# 	cust-12 ~ cust-3 ~ prod-1 ==> size: 3, diffs:[ 17  69 149]
# 	cust-12 ~ cust-3 ~ prod-3 ==> size: 2, diffs:[ 82 193]
# 	cust-12 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[164 241]
# 	cust-12 ~ cust-3 ~ prod-6 ==> size: 2, diffs:[ 12 142]
# 	cust-12 ~ cust-3 ~ prod-7 ==> size: 1, diffs:[8]
# 	cust-12 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[18]
# (12, 5) ->
#
# 	cust-12 ~ cust-5 ~ prod-1 ==> size: 3, diffs:[ 11  41 207]
# 	cust-12 ~ cust-5 ~ prod-3 ==> size: 2, diffs:[135 246]
# 	cust-12 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[ 83 214 268]
# 	cust-12 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 87 283]
# 	cust-12 ~ cust-5 ~ prod-8 ==> size: 2, diffs:[ 36 248]
# 	cust-12 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[215]
# (12, 6) ->
#
# 	cust-12 ~ cust-6 ~ prod-1 ==> size: 6, diffs:[10 81 85]
# 	cust-12 ~ cust-6 ~ prod-3 ==> size: 2, diffs:[ 15 126]
# 	cust-12 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[14]
# 	cust-12 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[148]
# 	cust-12 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[114]
# 	cust-12 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[155 235]
# (12, 24) ->
#
# 	cust-12 ~ cust-24 ~ prod-1 ==> size: 3, diffs:[  2 168 220]
# 	cust-12 ~ cust-24 ~ prod-3 ==> size: 2, diffs:[ 15 126]
# 	cust-12 ~ cust-24 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-12 ~ cust-24 ~ prod-5 ==> size: 1, diffs:[108]
# 	cust-12 ~ cust-24 ~ prod-6 ==> size: 1, diffs:[152]
# 	cust-12 ~ cust-24 ~ prod-8 ==> size: 2, diffs:[ 70 117]
# 	cust-12 ~ cust-24 ~ prod-9 ==> size: 2, diffs:[170 223]
# (12, 26) ->
#
# 	cust-12 ~ cust-26 ~ prod-1 ==> size: 3, diffs:[ 12  64 154]
# 	cust-12 ~ cust-26 ~ prod-3 ==> size: 2, diffs:[ 43 154]
# 	cust-12 ~ cust-26 ~ prod-6 ==> size: 1, diffs:[237]
# 	cust-12 ~ cust-26 ~ prod-7 ==> size: 1, diffs:[211]
# 	cust-12 ~ cust-26 ~ prod-8 ==> size: 1, diffs:[81]
# 	cust-12 ~ cust-26 ~ prod-9 ==> size: 1, diffs:[176]
# (12, 28) ->
#
# 	cust-12 ~ cust-28 ~ prod-1 ==> size: 3, diffs:[ 17 149 201]
# 	cust-12 ~ cust-28 ~ prod-3 ==> size: 4, diffs:[ 44  67 112]
# 	cust-12 ~ cust-28 ~ prod-4 ==> size: 1, diffs:[285]
# 	cust-12 ~ cust-28 ~ prod-5 ==> size: 2, diffs:[10 76]
# 	cust-12 ~ cust-28 ~ prod-6 ==> size: 1, diffs:[32]
# 	cust-12 ~ cust-28 ~ prod-7 ==> size: 1, diffs:[308]
# (12, 32) ->
#
# 	cust-12 ~ cust-32 ~ prod-1 ==> size: 6, diffs:[ 4 28 48]
# 	cust-12 ~ cust-32 ~ prod-4 ==> size: 1, diffs:[3]
# 	cust-12 ~ cust-32 ~ prod-6 ==> size: 2, diffs:[ 56 229]
# 	cust-12 ~ cust-32 ~ prod-7 ==> size: 3, diffs:[ 37 123 240]
# 	cust-12 ~ cust-32 ~ prod-8 ==> size: 2, diffs:[ 63 156]
# (13, 1) ->
#
# 	cust-13 ~ cust-1 ~ prod-0 ==> size: 6, diffs:[11 31 38]
# 	cust-13 ~ cust-1 ~ prod-2 ==> size: 1, diffs:[36]
# 	cust-13 ~ cust-1 ~ prod-3 ==> size: 2, diffs:[ 73 171]
# 	cust-13 ~ cust-1 ~ prod-4 ==> size: 2, diffs:[17 33]
# 	cust-13 ~ cust-1 ~ prod-5 ==> size: 1, diffs:[94]
# 	cust-13 ~ cust-1 ~ prod-6 ==> size: 1, diffs:[21]
# 	cust-13 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[94]
# 	cust-13 ~ cust-1 ~ prod-8 ==> size: 3, diffs:[211 240 327]
# (13, 5) ->
#
# 	cust-13 ~ cust-5 ~ prod-0 ==> size: 2, diffs:[ 79 148]
# 	cust-13 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[101]
# 	cust-13 ~ cust-5 ~ prod-3 ==> size: 2, diffs:[ 79 323]
# 	cust-13 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[ 63 194 248]
# 	cust-13 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 22 174]
# 	cust-13 ~ cust-5 ~ prod-8 ==> size: 2, diffs:[ 18 266]
# 	cust-13 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[288]
# (13, 8) ->
#
# 	cust-13 ~ cust-8 ~ prod-0 ==> size: 4, diffs:[23 46 58]
# 	cust-13 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[46]
# 	cust-13 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[  2 262]
# 	cust-13 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[113 196]
# 	cust-13 ~ cust-8 ~ prod-8 ==> size: 1, diffs:[32]
# 	cust-13 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[286]
# (13, 10) ->
#
# 	cust-13 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[118 224]
# 	cust-13 ~ cust-10 ~ prod-3 ==> size: 2, diffs:[ 86 158]
# 	cust-13 ~ cust-10 ~ prod-4 ==> size: 6, diffs:[ 10  40 108]
# 	cust-13 ~ cust-10 ~ prod-5 ==> size: 2, diffs:[23 40]
# 	cust-13 ~ cust-10 ~ prod-6 ==> size: 1, diffs:[27]
# 	cust-13 ~ cust-10 ~ prod-7 ==> size: 1, diffs:[128]
# 	cust-13 ~ cust-10 ~ prod-9 ==> size: 1, diffs:[224]
# (13, 20) ->
#
# 	cust-13 ~ cust-20 ~ prod-2 ==> size: 1, diffs:[227]
# 	cust-13 ~ cust-20 ~ prod-3 ==> size: 4, diffs:[  2  32 212]
# 	cust-13 ~ cust-20 ~ prod-4 ==> size: 4, diffs:[ 6 27 44]
# 	cust-13 ~ cust-20 ~ prod-6 ==> size: 1, diffs:[204]
# 	cust-13 ~ cust-20 ~ prod-7 ==> size: 1, diffs:[25]
# 	cust-13 ~ cust-20 ~ prod-8 ==> size: 2, diffs:[117 307]
# (14, 1) ->
#
# 	cust-14 ~ cust-1 ~ prod-2 ==> size: 1, diffs:[187]
# 	cust-14 ~ cust-1 ~ prod-4 ==> size: 1, diffs:[133]
# 	cust-14 ~ cust-1 ~ prod-5 ==> size: 2, diffs:[61 83]
# 	cust-14 ~ cust-1 ~ prod-6 ==> size: 1, diffs:[288]
# 	cust-14 ~ cust-1 ~ prod-8 ==> size: 6, diffs:[27 56 60]
# (14, 5) ->
#
# 	cust-14 ~ cust-5 ~ prod-1 ==> size: 2, diffs:[ 61 127]
# 	cust-14 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[50]
# 	cust-14 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[ 19  73 204]
# 	cust-14 ~ cust-5 ~ prod-8 ==> size: 4, diffs:[  1   6 285]
# 	cust-14 ~ cust-5 ~ prod-9 ==> size: 2, diffs:[ 55 157]
# (14, 6) ->
#
# 	cust-14 ~ cust-6 ~ prod-1 ==> size: 4, diffs:[187 253 258]
# 	cust-14 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[8]
# 	cust-14 ~ cust-6 ~ prod-5 ==> size: 2, diffs:[121 143]
# 	cust-14 ~ cust-6 ~ prod-8 ==> size: 4, diffs:[ 19  99 192]
# (14, 7) ->
#
# 	cust-14 ~ cust-7 ~ prod-1 ==> size: 4, diffs:[ 95 161 171]
# 	cust-14 ~ cust-7 ~ prod-5 ==> size: 2, diffs:[135 157]
# 	cust-14 ~ cust-7 ~ prod-9 ==> size: 4, diffs:[ 84  86 186]
# (14, 22) ->
#
# 	cust-14 ~ cust-22 ~ prod-1 ==> size: 2, diffs:[128 194]
# 	cust-14 ~ cust-22 ~ prod-2 ==> size: 1, diffs:[15]
# 	cust-14 ~ cust-22 ~ prod-4 ==> size: 2, diffs:[ 15 248]
# 	cust-14 ~ cust-22 ~ prod-5 ==> size: 2, diffs:[76 98]
# 	cust-14 ~ cust-22 ~ prod-6 ==> size: 1, diffs:[249]
# 	cust-14 ~ cust-22 ~ prod-8 ==> size: 4, diffs:[ 31 108 183]
# 	cust-14 ~ cust-22 ~ prod-9 ==> size: 2, diffs:[126 228]
# (14, 23) ->
#
# 	cust-14 ~ cust-23 ~ prod-1 ==> size: 2, diffs:[31 97]
# 	cust-14 ~ cust-23 ~ prod-2 ==> size: 1, diffs:[80]
# 	cust-14 ~ cust-23 ~ prod-5 ==> size: 2, diffs:[201 223]
# 	cust-14 ~ cust-23 ~ prod-9 ==> size: 4, diffs:[  1  35 101]
# (15, 3) ->
#
# 	cust-15 ~ cust-3 ~ prod-0 ==> size: 1, diffs:[176]
# 	cust-15 ~ cust-3 ~ prod-1 ==> size: 1, diffs:[179]
# 	cust-15 ~ cust-3 ~ prod-3 ==> size: 2, diffs:[ 88 343]
# 	cust-15 ~ cust-3 ~ prod-4 ==> size: 2, diffs:[ 83 160]
# 	cust-15 ~ cust-3 ~ prod-6 ==> size: 4, diffs:[ 26  43 104]
# 	cust-15 ~ cust-3 ~ prod-7 ==> size: 2, diffs:[  7 131]
# 	cust-15 ~ cust-3 ~ prod-9 ==> size: 1, diffs:[4]
# (15, 5) ->
#
# 	cust-15 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[22]
# 	cust-15 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[121]
# 	cust-15 ~ cust-5 ~ prod-3 ==> size: 2, diffs:[ 15 240]
# 	cust-15 ~ cust-5 ~ prod-6 ==> size: 6, diffs:[29 33 83]
# 	cust-15 ~ cust-5 ~ prod-7 ==> size: 4, diffs:[ 52  86 144]
# 	cust-15 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[237]
# (15, 10) ->
#
# 	cust-15 ~ cust-10 ~ prod-3 ==> size: 2, diffs:[  3 252]
# 	cust-15 ~ cust-10 ~ prod-4 ==> size: 3, diffs:[ 81 199 230]
# 	cust-15 ~ cust-10 ~ prod-6 ==> size: 2, diffs:[123 192]
# 	cust-15 ~ cust-10 ~ prod-7 ==> size: 2, diffs:[ 20 158]
# 	cust-15 ~ cust-10 ~ prod-9 ==> size: 1, diffs:[173]
# (15, 11) ->
#
# 	cust-15 ~ cust-11 ~ prod-0 ==> size: 1, diffs:[27]
# 	cust-15 ~ cust-11 ~ prod-4 ==> size: 1, diffs:[43]
# 	cust-15 ~ cust-11 ~ prod-7 ==> size: 6, diffs:[ 10  24 117]
# 	cust-15 ~ cust-11 ~ prod-9 ==> size: 1, diffs:[35]
# (15, 23) ->
#
# 	cust-15 ~ cust-23 ~ prod-0 ==> size: 2, diffs:[ 71 208]
# 	cust-15 ~ cust-23 ~ prod-1 ==> size: 1, diffs:[91]
# 	cust-15 ~ cust-23 ~ prod-3 ==> size: 2, diffs:[ 81 174]
# 	cust-15 ~ cust-23 ~ prod-7 ==> size: 2, diffs:[  6 144]
# 	cust-15 ~ cust-23 ~ prod-9 ==> size: 2, diffs:[181 217]
# (15, 30) ->
#
# 	cust-15 ~ cust-30 ~ prod-0 ==> size: 1, diffs:[1]
# 	cust-15 ~ cust-30 ~ prod-1 ==> size: 1, diffs:[185]
# 	cust-15 ~ cust-30 ~ prod-3 ==> size: 2, diffs:[ 74 181]
# 	cust-15 ~ cust-30 ~ prod-4 ==> size: 1, diffs:[228]
# 	cust-15 ~ cust-30 ~ prod-7 ==> size: 2, diffs:[58 80]
# (16, 0) ->
#
# 	cust-16 ~ cust-0 ~ prod-6 ==> size: 6, diffs:[ 34  60 132]
# 	cust-16 ~ cust-0 ~ prod-8 ==> size: 9, diffs:[ 9 19 46]
# (16, 3) ->
#
# 	cust-16 ~ cust-3 ~ prod-0 ==> size: 1, diffs:[24]
# 	cust-16 ~ cust-3 ~ prod-6 ==> size: 6, diffs:[36 55 81]
# 	cust-16 ~ cust-3 ~ prod-7 ==> size: 2, diffs:[  8 303]
# 	cust-16 ~ cust-3 ~ prod-9 ==> size: 2, diffs:[26 38]
# (16, 7) ->
#
# 	cust-16 ~ cust-7 ~ prod-0 ==> size: 2, diffs:[ 51 269]
# 	cust-16 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[65]
# 	cust-16 ~ cust-7 ~ prod-7 ==> size: 2, diffs:[144 151]
# 	cust-16 ~ cust-7 ~ prod-9 ==> size: 4, diffs:[ 16  48 224]
# (16, 9) ->
#
# 	cust-16 ~ cust-9 ~ prod-0 ==> size: 2, diffs:[ 17 124]
# 	cust-16 ~ cust-9 ~ prod-6 ==> size: 6, diffs:[ 7 19 88]
# 	cust-16 ~ cust-9 ~ prod-8 ==> size: 6, diffs:[ 16  35 109]
# 	cust-16 ~ cust-9 ~ prod-9 ==> size: 2, diffs:[ 52 116]
# (17, 1) ->
#
# 	cust-17 ~ cust-1 ~ prod-0 ==> size: 6, diffs:[ 8 37 79]
# 	cust-17 ~ cust-1 ~ prod-2 ==> size: 2, diffs:[ 67 180]
# 	cust-17 ~ cust-1 ~ prod-3 ==> size: 2, diffs:[112 122]
# 	cust-17 ~ cust-1 ~ prod-6 ==> size: 2, diffs:[28 90]
# 	cust-17 ~ cust-1 ~ prod-8 ==> size: 3, diffs:[110 139 226]
# (17, 6) ->
#
# 	cust-17 ~ cust-6 ~ prod-3 ==> size: 2, diffs:[ 80 154]
# 	cust-17 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 26 106]
# (17, 7) ->
#
# 	cust-17 ~ cust-7 ~ prod-0 ==> size: 4, diffs:[ 73 103 115]
# 	cust-17 ~ cust-7 ~ prod-3 ==> size: 4, diffs:[ 20  25 209]
# 	cust-17 ~ cust-7 ~ prod-9 ==> size: 2, diffs:[ 32 304]
# (17, 8) ->
#
# 	cust-17 ~ cust-8 ~ prod-0 ==> size: 4, diffs:[  1  71 105]
# 	cust-17 ~ cust-8 ~ prod-2 ==> size: 2, diffs:[15 98]
# 	cust-17 ~ cust-8 ~ prod-6 ==> size: 4, diffs:[ 51  67 193]
# 	cust-17 ~ cust-8 ~ prod-8 ==> size: 1, diffs:[133]
# 	cust-17 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[63]
# (18, 0) ->
#
# 	cust-18 ~ cust-0 ~ prod-1 ==> size: 8, diffs:[24 57 68]
# 	cust-18 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[7]
# 	cust-18 ~ cust-0 ~ prod-8 ==> size: 9, diffs:[ 1 36 38]
# (18, 5) ->
#
# 	cust-18 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[224]
# 	cust-18 ~ cust-5 ~ prod-1 ==> size: 4, diffs:[ 40  79 121]
# 	cust-18 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[63]
# 	cust-18 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[  2 198]
# 	cust-18 ~ cust-5 ~ prod-8 ==> size: 6, diffs:[ 54  75 126]
# 	cust-18 ~ cust-5 ~ prod-9 ==> size: 1, diffs:[56]
# (18, 8) ->
#
# 	cust-18 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[ 99 203]
# 	cust-18 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[118]
# 	cust-18 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[20 63]
# 	cust-18 ~ cust-8 ~ prod-8 ==> size: 3, diffs:[ 89 140 244]
# 	cust-18 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[58]
# (18, 10) ->
#
# 	cust-18 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[46 60]
# 	cust-18 ~ cust-10 ~ prod-5 ==> size: 2, diffs:[ 62 125]
# 	cust-18 ~ cust-10 ~ prod-7 ==> size: 1, diffs:[304]
# 	cust-18 ~ cust-10 ~ prod-9 ==> size: 1, diffs:[120]
# (18, 19) ->
#
# 	cust-18 ~ cust-19 ~ prod-1 ==> size: 4, diffs:[ 12  61 107]
# 	cust-18 ~ cust-19 ~ prod-2 ==> size: 1, diffs:[147]
# 	cust-18 ~ cust-19 ~ prod-5 ==> size: 1, diffs:[164]
# 	cust-18 ~ cust-19 ~ prod-7 ==> size: 3, diffs:[ 92 229 327]
# 	cust-18 ~ cust-19 ~ prod-8 ==> size: 6, diffs:[21 30 30]
# 	cust-18 ~ cust-19 ~ prod-9 ==> size: 2, diffs:[197 244]
# (18, 21) ->
#
# 	cust-18 ~ cust-21 ~ prod-1 ==> size: 4, diffs:[ 20  29 139]
# 	cust-18 ~ cust-21 ~ prod-2 ==> size: 1, diffs:[24]
# 	cust-18 ~ cust-21 ~ prod-5 ==> size: 2, diffs:[ 81 140]
# 	cust-18 ~ cust-21 ~ prod-9 ==> size: 1, diffs:[49]
# (18, 27) ->
#
# 	cust-18 ~ cust-27 ~ prod-1 ==> size: 4, diffs:[  3  46 122]
# 	cust-18 ~ cust-27 ~ prod-5 ==> size: 1, diffs:[78]
# 	cust-18 ~ cust-27 ~ prod-7 ==> size: 1, diffs:[255]
# 	cust-18 ~ cust-27 ~ prod-8 ==> size: 3, diffs:[ 50  54 101]
# 	cust-18 ~ cust-27 ~ prod-9 ==> size: 3, diffs:[ 21 255 347]
# (18, 29) ->
#
# 	cust-18 ~ cust-29 ~ prod-0 ==> size: 1, diffs:[68]
# 	cust-18 ~ cust-29 ~ prod-1 ==> size: 4, diffs:[  2  47 121]
# 	cust-18 ~ cust-29 ~ prod-2 ==> size: 1, diffs:[3]
# 	cust-18 ~ cust-29 ~ prod-5 ==> size: 3, diffs:[ 57 132 195]
# 	cust-18 ~ cust-29 ~ prod-8 ==> size: 3, diffs:[ 45  96 200]
# (18, 31) ->
#
# 	cust-18 ~ cust-31 ~ prod-2 ==> size: 1, diffs:[37]
# 	cust-18 ~ cust-31 ~ prod-5 ==> size: 1, diffs:[16]
# 	cust-18 ~ cust-31 ~ prod-7 ==> size: 2, diffs:[ 47 155]
# 	cust-18 ~ cust-31 ~ prod-8 ==> size: 6, diffs:[34 67 85]
# (19, 6) ->
#
# 	cust-19 ~ cust-6 ~ prod-1 ==> size: 2, diffs:[193 264]
# 	cust-19 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[20]
# 	cust-19 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[232]
# 	cust-19 ~ cust-6 ~ prod-7 ==> size: 3, diffs:[ 58  79 156]
# 	cust-19 ~ cust-6 ~ prod-8 ==> size: 4, diffs:[12 63 92]
# (19, 8) ->
#
# 	cust-19 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[29]
# 	cust-19 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 67 327]
# 	cust-19 ~ cust-8 ~ prod-7 ==> size: 6, diffs:[ 29 112 166]
# 	cust-19 ~ cust-8 ~ prod-8 ==> size: 2, diffs:[119 170]
# 	cust-19 ~ cust-8 ~ prod-9 ==> size: 2, diffs:[139 186]
# (19, 10) ->
#
# 	cust-19 ~ cust-10 ~ prod-2 ==> size: 2, diffs:[101 207]
# 	cust-19 ~ cust-10 ~ prod-4 ==> size: 3, diffs:[128 246 277]
# 	cust-19 ~ cust-10 ~ prod-5 ==> size: 2, diffs:[226 289]
# 	cust-19 ~ cust-10 ~ prod-6 ==> size: 1, diffs:[38]
# 	cust-19 ~ cust-10 ~ prod-7 ==> size: 3, diffs:[ 23  75 212]
# 	cust-19 ~ cust-10 ~ prod-9 ==> size: 2, diffs:[ 77 124]
# (19, 18) ->
#
# 	cust-19 ~ cust-18 ~ prod-1 ==> size: 4, diffs:[ 12  61 107]
# 	cust-19 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[147]
# 	cust-19 ~ cust-18 ~ prod-5 ==> size: 1, diffs:[164]
# 	cust-19 ~ cust-18 ~ prod-7 ==> size: 3, diffs:[ 92 229 327]
# 	cust-19 ~ cust-18 ~ prod-8 ==> size: 6, diffs:[21 30 30]
# 	cust-19 ~ cust-18 ~ prod-9 ==> size: 2, diffs:[197 244]
# (20, 3) ->
#
# 	cust-20 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[29]
# 	cust-20 ~ cust-3 ~ prod-3 ==> size: 2, diffs:[  3 217]
# 	cust-20 ~ cust-3 ~ prod-4 ==> size: 4, diffs:[ 2 69 75]
# 	cust-20 ~ cust-3 ~ prod-6 ==> size: 2, diffs:[ 82 212]
# 	cust-20 ~ cust-3 ~ prod-7 ==> size: 1, diffs:[76]
# (20, 6) ->
#
# 	cust-20 ~ cust-6 ~ prod-3 ==> size: 2, diffs:[  9 205]
# ...
# 	cust-22 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 16 244]
# 	cust-22 ~ cust-8 ~ prod-8 ==> size: 2, diffs:[116 268]
# 	cust-22 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[281]
# (22, 9) ->
#
# 	cust-22 ~ cust-9 ~ prod-1 ==> size: 1, diffs:[109]
# 	cust-22 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[127 165]
# 	cust-22 ~ cust-9 ~ prod-4 ==> size: 2, diffs:[ 88 145]
# 	cust-22 ~ cust-9 ~ prod-6 ==> size: 2, diffs:[166 273]
# 	cust-22 ~ cust-9 ~ prod-8 ==> size: 4, diffs:[ 25  68 127]
# 	cust-22 ~ cust-9 ~ prod-9 ==> size: 1, diffs:[140]
# (22, 14) ->
#
# 	cust-22 ~ cust-14 ~ prod-1 ==> size: 2, diffs:[128 194]
# 	cust-22 ~ cust-14 ~ prod-2 ==> size: 1, diffs:[15]
# 	cust-22 ~ cust-14 ~ prod-4 ==> size: 2, diffs:[ 15 248]
# 	cust-22 ~ cust-14 ~ prod-5 ==> size: 2, diffs:[76 98]
# 	cust-22 ~ cust-14 ~ prod-6 ==> size: 1, diffs:[249]
# 	cust-22 ~ cust-14 ~ prod-8 ==> size: 4, diffs:[ 31 108 183]
# 	cust-22 ~ cust-14 ~ prod-9 ==> size: 2, diffs:[126 228]
# (23, 6) ->
#
# 	cust-23 ~ cust-6 ~ prod-1 ==> size: 2, diffs:[156 227]
# 	cust-23 ~ cust-6 ~ prod-3 ==> size: 1, diffs:[39]
# 	cust-23 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[80]
# 	cust-23 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[31]
# (23, 9) ->
#
# 	cust-23 ~ cust-9 ~ prod-0 ==> size: 4, diffs:[ 39  99 180]
# 	cust-23 ~ cust-9 ~ prod-1 ==> size: 1, diffs:[12]
# 	cust-23 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[192 230]
# 	cust-23 ~ cust-9 ~ prod-9 ==> size: 2, diffs:[ 87 123]
# (23, 14) ->
#
# 	cust-23 ~ cust-14 ~ prod-1 ==> size: 2, diffs:[31 97]
# 	cust-23 ~ cust-14 ~ prod-2 ==> size: 1, diffs:[80]
# 	cust-23 ~ cust-14 ~ prod-5 ==> size: 2, diffs:[201 223]
# 	cust-23 ~ cust-14 ~ prod-9 ==> size: 4, diffs:[  1  35 101]
# (23, 15) ->
#
# 	cust-23 ~ cust-15 ~ prod-0 ==> size: 2, diffs:[ 71 208]
# 	cust-23 ~ cust-15 ~ prod-1 ==> size: 1, diffs:[91]
# 	cust-23 ~ cust-15 ~ prod-3 ==> size: 2, diffs:[ 81 174]
# 	cust-23 ~ cust-15 ~ prod-7 ==> size: 2, diffs:[  6 144]
# 	cust-23 ~ cust-15 ~ prod-9 ==> size: 2, diffs:[181 217]
# (23, 24) ->
#
# 	cust-23 ~ cust-24 ~ prod-0 ==> size: 2, diffs:[  2 281]
# 	cust-23 ~ cust-24 ~ prod-1 ==> size: 1, diffs:[239]
# 	cust-23 ~ cust-24 ~ prod-3 ==> size: 1, diffs:[102]
# 	cust-23 ~ cust-24 ~ prod-5 ==> size: 1, diffs:[120]
# 	cust-23 ~ cust-24 ~ prod-9 ==> size: 4, diffs:[11 25 28]
# (24, 0) ->
#
# 	cust-24 ~ cust-0 ~ prod-1 ==> size: 2, diffs:[ 20 112]
# 	cust-24 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[119]
# 	cust-24 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[205]
# 	cust-24 ~ cust-0 ~ prod-6 ==> size: 2, diffs:[105 178]
# 	cust-24 ~ cust-0 ~ prod-8 ==> size: 6, diffs:[16 31 53]
# (24, 5) ->
#
# 	cust-24 ~ cust-5 ~ prod-0 ==> size: 1, diffs:[51]
# 	cust-24 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[209]
# 	cust-24 ~ cust-5 ~ prod-3 ==> size: 1, diffs:[261]
# 	cust-24 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[ 62  69 116]
# 	cust-24 ~ cust-5 ~ prod-8 ==> size: 4, diffs:[106 131 153]
# 	cust-24 ~ cust-5 ~ prod-9 ==> size: 2, diffs:[ 8 45]
# (24, 12) ->
#
# 	cust-24 ~ cust-12 ~ prod-1 ==> size: 3, diffs:[  2 168 220]
# 	cust-24 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[ 15 126]
# 	cust-24 ~ cust-12 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-24 ~ cust-12 ~ prod-5 ==> size: 1, diffs:[108]
# 	cust-24 ~ cust-12 ~ prod-6 ==> size: 1, diffs:[152]
# 	cust-24 ~ cust-12 ~ prod-8 ==> size: 2, diffs:[ 70 117]
# 	cust-24 ~ cust-12 ~ prod-9 ==> size: 2, diffs:[170 223]
# (24, 23) ->
#
# 	cust-24 ~ cust-23 ~ prod-0 ==> size: 2, diffs:[  2 281]
# 	cust-24 ~ cust-23 ~ prod-1 ==> size: 1, diffs:[239]
# 	cust-24 ~ cust-23 ~ prod-3 ==> size: 1, diffs:[102]
# 	cust-24 ~ cust-23 ~ prod-5 ==> size: 1, diffs:[120]
# 	cust-24 ~ cust-23 ~ prod-9 ==> size: 4, diffs:[11 25 28]
# (24, 28) ->
#
# 	cust-24 ~ cust-28 ~ prod-0 ==> size: 1, diffs:[62]
# 	cust-24 ~ cust-28 ~ prod-1 ==> size: 1, diffs:[19]
# 	cust-24 ~ cust-28 ~ prod-3 ==> size: 2, diffs:[ 82 238]
# 	cust-24 ~ cust-28 ~ prod-4 ==> size: 1, diffs:[270]
# 	cust-24 ~ cust-28 ~ prod-5 ==> size: 2, diffs:[ 32 118]
# 	cust-24 ~ cust-28 ~ prod-6 ==> size: 1, diffs:[120]
# (24, 30) ->
#
# 	cust-24 ~ cust-30 ~ prod-0 ==> size: 1, diffs:[74]
# 	cust-24 ~ cust-30 ~ prod-1 ==> size: 1, diffs:[145]
# 	cust-24 ~ cust-30 ~ prod-3 ==> size: 1, diffs:[202]
# 	cust-24 ~ cust-30 ~ prod-4 ==> size: 1, diffs:[294]
# 	cust-24 ~ cust-30 ~ prod-8 ==> size: 6, diffs:[132 134 148]
# (25, 0) ->
#
# 	cust-25 ~ cust-0 ~ prod-2 ==> size: 1, diffs:[107]
# 	cust-25 ~ cust-0 ~ prod-4 ==> size: 2, diffs:[ 24 122]
# (25, 3) ->
#
# 	cust-25 ~ cust-3 ~ prod-0 ==> size: 3, diffs:[ 53 142 272]
# 	cust-25 ~ cust-3 ~ prod-2 ==> size: 1, diffs:[134]
# 	cust-25 ~ cust-3 ~ prod-4 ==> size: 4, diffs:[32 45 66]
# 	cust-25 ~ cust-3 ~ prod-7 ==> size: 1, diffs:[4]
# 	cust-25 ~ cust-3 ~ prod-9 ==> size: 2, diffs:[ 9 16]
# (25, 5) ->
#
# 	cust-25 ~ cust-5 ~ prod-0 ==> size: 3, diffs:[ 56  74 251]
# 	cust-25 ~ cust-5 ~ prod-2 ==> size: 1, diffs:[37]
# 	cust-25 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 75 271]
# 	cust-25 ~ cust-5 ~ prod-9 ==> size: 2, diffs:[242 249]
# (25, 6) ->
#
# 	cust-25 ~ cust-6 ~ prod-4 ==> size: 2, diffs:[ 84 182]
# 	cust-25 ~ cust-6 ~ prod-5 ==> size: 2, diffs:[ 53 203]
# 	cust-25 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[102]
# (26, 6) ->
#
# 	cust-26 ~ cust-6 ~ prod-1 ==> size: 2, diffs:[ 73 144]
# 	cust-26 ~ cust-6 ~ prod-3 ==> size: 1, diffs:[169]
# 	cust-26 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[97]
# 	cust-26 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 74 154]
# (26, 7) ->
#
# 	cust-26 ~ cust-7 ~ prod-0 ==> size: 2, diffs:[  3 215]
# 	cust-26 ~ cust-7 ~ prod-1 ==> size: 2, diffs:[19 57]
# 	cust-26 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[ 35 224]
# 	cust-26 ~ cust-7 ~ prod-7 ==> size: 1, diffs:[51]
# 	cust-26 ~ cust-7 ~ prod-9 ==> size: 2, diffs:[ 68 204]
# (26, 8) ->
#
# 	cust-26 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[113 217]
# 	cust-26 ~ cust-8 ~ prod-2 ==> size: 4, diffs:[ 83 131 194]
# 	cust-26 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 45 215]
# 	cust-26 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[11 94]
# 	cust-26 ~ cust-8 ~ prod-8 ==> size: 1, diffs:[181]
# 	cust-26 ~ cust-8 ~ prod-9 ==> size: 1, diffs:[37]
# (26, 12) ->
#
# 	cust-26 ~ cust-12 ~ prod-1 ==> size: 3, diffs:[ 12  64 154]
# 	cust-26 ~ cust-12 ~ prod-3 ==> size: 2, diffs:[ 43 154]
# 	cust-26 ~ cust-12 ~ prod-6 ==> size: 1, diffs:[237]
# 	cust-26 ~ cust-12 ~ prod-7 ==> size: 1, diffs:[211]
# 	cust-26 ~ cust-12 ~ prod-8 ==> size: 1, diffs:[81]
# 	cust-26 ~ cust-12 ~ prod-9 ==> size: 1, diffs:[176]
# (26, 33) ->
#
# 	cust-26 ~ cust-33 ~ prod-1 ==> size: 1, diffs:[93]
# 	cust-26 ~ cust-33 ~ prod-6 ==> size: 1, diffs:[33]
# 	cust-26 ~ cust-33 ~ prod-7 ==> size: 2, diffs:[ 29 167]
# 	cust-26 ~ cust-33 ~ prod-9 ==> size: 3, diffs:[ 22 188 215]
# (27, 5) ->
#
# 	cust-27 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[82]
# 	cust-27 ~ cust-5 ~ prod-7 ==> size: 2, diffs:[ 57 253]
# 	cust-27 ~ cust-5 ~ prod-8 ==> size: 2, diffs:[108 176]
# 	cust-27 ~ cust-5 ~ prod-9 ==> size: 3, diffs:[ 35 199 291]
# (27, 6) ->
#
# 	cust-27 ~ cust-6 ~ prod-1 ==> size: 2, diffs:[208 279]
# 	cust-27 ~ cust-6 ~ prod-4 ==> size: 1, diffs:[288]
# 	cust-27 ~ cust-6 ~ prod-5 ==> size: 1, diffs:[146]
# 	cust-27 ~ cust-6 ~ prod-7 ==> size: 1, diffs:[84]
# 	cust-27 ~ cust-6 ~ prod-8 ==> size: 2, diffs:[ 83 163]
# (27, 18) ->
#
# 	cust-27 ~ cust-18 ~ prod-1 ==> size: 4, diffs:[  3  46 122]
# 	cust-27 ~ cust-18 ~ prod-5 ==> size: 1, diffs:[78]
# 	cust-27 ~ cust-18 ~ prod-7 ==> size: 1, diffs:[255]
# 	cust-27 ~ cust-18 ~ prod-8 ==> size: 3, diffs:[ 50  54 101]
# 	cust-27 ~ cust-18 ~ prod-9 ==> size: 3, diffs:[ 21 255 347]
# (27, 21) ->
#
# 	cust-27 ~ cust-21 ~ prod-1 ==> size: 1, diffs:[17]
# 	cust-27 ~ cust-21 ~ prod-4 ==> size: 2, diffs:[ 31 110]
# 	cust-27 ~ cust-21 ~ prod-5 ==> size: 2, diffs:[ 3 62]
# 	cust-27 ~ cust-21 ~ prod-9 ==> size: 3, diffs:[ 28 206 298]
# (27, 30) ->
#
# 	cust-27 ~ cust-30 ~ prod-1 ==> size: 1, diffs:[146]
# 	cust-27 ~ cust-30 ~ prod-4 ==> size: 1, diffs:[7]
# 	cust-27 ~ cust-30 ~ prod-7 ==> size: 1, diffs:[29]
# 	cust-27 ~ cust-30 ~ prod-8 ==> size: 3, diffs:[134 150 179]
# (27, 33) ->
#
# 	cust-27 ~ cust-33 ~ prod-1 ==> size: 1, diffs:[42]
# 	cust-27 ~ cust-33 ~ prod-4 ==> size: 1, diffs:[24]
# 	cust-27 ~ cust-33 ~ prod-5 ==> size: 2, diffs:[30 38]
# 	cust-27 ~ cust-33 ~ prod-7 ==> size: 2, diffs:[ 14 152]
# 	cust-27 ~ cust-33 ~ prod-9 ==> size: 9, diffs:[28 37 55]
# (27, 34) ->
#
# 	cust-27 ~ cust-34 ~ prod-4 ==> size: 1, diffs:[97]
# 	cust-27 ~ cust-34 ~ prod-5 ==> size: 1, diffs:[46]
# 	cust-27 ~ cust-34 ~ prod-7 ==> size: 2, diffs:[157 212]
# 	cust-27 ~ cust-34 ~ prod-9 ==> size: 6, diffs:[12 39 53]
# (28, 1) ->
#
# 	cust-28 ~ cust-1 ~ prod-0 ==> size: 3, diffs:[106 148 177]
# 	cust-28 ~ cust-1 ~ prod-2 ==> size: 1, diffs:[191]
# 	cust-28 ~ cust-1 ~ prod-3 ==> size: 2, diffs:[ 27 129]
# 	cust-28 ~ cust-1 ~ prod-4 ==> size: 1, diffs:[130]
# 	cust-28 ~ cust-1 ~ prod-5 ==> size: 2, diffs:[12 98]
# 	cust-28 ~ cust-1 ~ prod-6 ==> size: 1, diffs:[33]
# 	cust-28 ~ cust-1 ~ prod-7 ==> size: 1, diffs:[293]
# (28, 8) ->
#
# 	cust-28 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[ 10 114]
# 	cust-28 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[109]
# 	cust-28 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 10 250]
# 	cust-28 ~ cust-8 ~ prod-7 ==> size: 2, diffs:[ 3 86]
# (28, 12) ->
#
# 	cust-28 ~ cust-12 ~ prod-1 ==> size: 3, diffs:[ 17 149 201]
# 	cust-28 ~ cust-12 ~ prod-3 ==> size: 4, diffs:[ 44  67 112]
# 	cust-28 ~ cust-12 ~ prod-4 ==> size: 1, diffs:[285]
# 	cust-28 ~ cust-12 ~ prod-5 ==> size: 2, diffs:[10 76]
# 	cust-28 ~ cust-12 ~ prod-6 ==> size: 1, diffs:[32]
# 	cust-28 ~ cust-12 ~ prod-7 ==> size: 1, diffs:[308]
# (28, 24) ->
#
# 	cust-28 ~ cust-24 ~ prod-0 ==> size: 1, diffs:[62]
# 	cust-28 ~ cust-24 ~ prod-1 ==> size: 1, diffs:[19]
# 	cust-28 ~ cust-24 ~ prod-3 ==> size: 2, diffs:[ 82 238]
# 	cust-28 ~ cust-24 ~ prod-4 ==> size: 1, diffs:[270]
# 	cust-28 ~ cust-24 ~ prod-5 ==> size: 2, diffs:[ 32 118]
# 	cust-28 ~ cust-24 ~ prod-6 ==> size: 1, diffs:[120]
# (28, 29) ->
#
# 	cust-28 ~ cust-29 ~ prod-0 ==> size: 1, diffs:[145]
# 	cust-28 ~ cust-29 ~ prod-1 ==> size: 1, diffs:[271]
# 	cust-28 ~ cust-29 ~ prod-2 ==> size: 1, diffs:[6]
# 	cust-28 ~ cust-29 ~ prod-4 ==> size: 3, diffs:[ 58 238 288]
# 	cust-28 ~ cust-29 ~ prod-5 ==> size: 6, diffs:[33 42 53]
# 	cust-28 ~ cust-29 ~ prod-6 ==> size: 1, diffs:[97]
# (28, 32) ->
#
# 	cust-28 ~ cust-32 ~ prod-1 ==> size: 2, diffs:[121 197]
# 	cust-28 ~ cust-32 ~ prod-4 ==> size: 1, diffs:[282]
# 	cust-28 ~ cust-32 ~ prod-6 ==> size: 2, diffs:[ 24 197]
# 	cust-28 ~ cust-32 ~ prod-7 ==> size: 3, diffs:[ 68 185 345]
# (29, 8) ->
#
# 	cust-29 ~ cust-8 ~ prod-0 ==> size: 2, diffs:[ 31 135]
# 	cust-29 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[115]
# 	cust-29 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[107 153]
# 	cust-29 ~ cust-8 ~ prod-8 ==> size: 1, diffs:[44]
# (29, 9) ->
#
# 	cust-29 ~ cust-9 ~ prod-0 ==> size: 2, diffs:[ 35 106]
# 	cust-29 ~ cust-9 ~ prod-1 ==> size: 1, diffs:[39]
# 	cust-29 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[102 140]
# 	cust-29 ~ cust-9 ~ prod-4 ==> size: 3, diffs:[ 45 135 185]
# 	cust-29 ~ cust-9 ~ prod-6 ==> size: 2, diffs:[ 75 182]
# 	cust-29 ~ cust-9 ~ prod-8 ==> size: 2, diffs:[ 4 97]
# (29, 18) ->
#
# 	cust-29 ~ cust-18 ~ prod-0 ==> size: 1, diffs:[68]
# 	cust-29 ~ cust-18 ~ prod-1 ==> size: 4, diffs:[  2  47 121]
# 	cust-29 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[3]
# 	cust-29 ~ cust-18 ~ prod-5 ==> size: 3, diffs:[ 57 132 195]
# 	cust-29 ~ cust-18 ~ prod-8 ==> size: 3, diffs:[ 45  96 200]
# (29, 28) ->
#
# 	cust-29 ~ cust-28 ~ prod-0 ==> size: 1, diffs:[145]
# 	cust-29 ~ cust-28 ~ prod-1 ==> size: 1, diffs:[271]
# 	cust-29 ~ cust-28 ~ prod-2 ==> size: 1, diffs:[6]
# 	cust-29 ~ cust-28 ~ prod-4 ==> size: 3, diffs:[ 58 238 288]
# 	cust-29 ~ cust-28 ~ prod-5 ==> size: 6, diffs:[33 42 53]
# 	cust-29 ~ cust-28 ~ prod-6 ==> size: 1, diffs:[97]
# (30, 0) ->
#
# 	cust-30 ~ cust-0 ~ prod-1 ==> size: 2, diffs:[ 33 125]
# 	cust-30 ~ cust-0 ~ prod-2 ==> size: 2, diffs:[35 64]
# 	cust-30 ~ cust-0 ~ prod-3 ==> size: 1, diffs:[83]
# 	cust-30 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[89]
# 	cust-30 ~ cust-0 ~ prod-8 ==> size: 9, diffs:[42 58 79]
# (30, 15) ->
#
# 	cust-30 ~ cust-15 ~ prod-0 ==> size: 1, diffs:[1]
# 	cust-30 ~ cust-15 ~ prod-1 ==> size: 1, diffs:[185]
# 	cust-30 ~ cust-15 ~ prod-3 ==> size: 2, diffs:[ 74 181]
# 	cust-30 ~ cust-15 ~ prod-4 ==> size: 1, diffs:[228]
# 	cust-30 ~ cust-15 ~ prod-7 ==> size: 2, diffs:[58 80]
# (30, 24) ->
#
# 	cust-30 ~ cust-24 ~ prod-0 ==> size: 1, diffs:[74]
# 	cust-30 ~ cust-24 ~ prod-1 ==> size: 1, diffs:[145]
# 	cust-30 ~ cust-24 ~ prod-3 ==> size: 1, diffs:[202]
# 	cust-30 ~ cust-24 ~ prod-4 ==> size: 1, diffs:[294]
# 	cust-30 ~ cust-24 ~ prod-8 ==> size: 6, diffs:[132 134 148]
# (30, 27) ->
#
# 	cust-30 ~ cust-27 ~ prod-1 ==> size: 1, diffs:[146]
# 	cust-30 ~ cust-27 ~ prod-4 ==> size: 1, diffs:[7]
# 	cust-30 ~ cust-27 ~ prod-7 ==> size: 1, diffs:[29]
# 	cust-30 ~ cust-27 ~ prod-8 ==> size: 3, diffs:[134 150 179]
# (31, 7) ->
#
# 	cust-31 ~ cust-7 ~ prod-3 ==> size: 2, diffs:[  1 188]
# 	cust-31 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[66]
# 	cust-31 ~ cust-7 ~ prod-7 ==> size: 2, diffs:[30 78]
# (31, 8) ->
#
# 	cust-31 ~ cust-8 ~ prod-2 ==> size: 1, diffs:[81]
# 	cust-31 ~ cust-8 ~ prod-6 ==> size: 6, diffs:[13 64 75]
# 	cust-31 ~ cust-8 ~ prod-7 ==> size: 4, diffs:[16 67 92]
# 	cust-31 ~ cust-8 ~ prod-8 ==> size: 2, diffs:[22 55]
# (31, 9) ->
#
# 	cust-31 ~ cust-9 ~ prod-2 ==> size: 2, diffs:[136 174]
# 	cust-31 ~ cust-9 ~ prod-4 ==> size: 2, diffs:[ 26 107]
# 	cust-31 ~ cust-9 ~ prod-6 ==> size: 6, diffs:[  3 104 195]
# 	cust-31 ~ cust-9 ~ prod-8 ==> size: 4, diffs:[ 7 26 86]
# (31, 18) ->
#
# 	cust-31 ~ cust-18 ~ prod-2 ==> size: 1, diffs:[37]
# 	cust-31 ~ cust-18 ~ prod-5 ==> size: 1, diffs:[16]
# 	cust-31 ~ cust-18 ~ prod-7 ==> size: 2, diffs:[ 47 155]
# 	cust-31 ~ cust-18 ~ prod-8 ==> size: 6, diffs:[34 67 85]
# (32, 2) ->
#
# 	cust-32 ~ cust-2 ~ prod-1 ==> size: 6, diffs:[ 3 19 42]
# 	cust-32 ~ cust-2 ~ prod-4 ==> size: 1, diffs:[4]
# 	cust-32 ~ cust-2 ~ prod-8 ==> size: 2, diffs:[ 70 289]
# (32, 9) ->
#
# 	cust-32 ~ cust-9 ~ prod-1 ==> size: 2, diffs:[ 35 111]
# 	cust-32 ~ cust-9 ~ prod-4 ==> size: 1, diffs:[179]
# 	cust-32 ~ cust-9 ~ prod-6 ==> size: 4, diffs:[ 25  82 148]
# 	cust-32 ~ cust-9 ~ prod-8 ==> size: 4, diffs:[ 35  58 184]
# (32, 12) ->
#
# 	cust-32 ~ cust-12 ~ prod-1 ==> size: 6, diffs:[ 4 28 48]
# 	cust-32 ~ cust-12 ~ prod-4 ==> size: 1, diffs:[3]
# 	cust-32 ~ cust-12 ~ prod-6 ==> size: 2, diffs:[ 56 229]
# 	cust-32 ~ cust-12 ~ prod-7 ==> size: 3, diffs:[ 37 123 240]
# 	cust-32 ~ cust-12 ~ prod-8 ==> size: 2, diffs:[ 63 156]
# (32, 28) ->
#
# 	cust-32 ~ cust-28 ~ prod-1 ==> size: 2, diffs:[121 197]
# 	cust-32 ~ cust-28 ~ prod-4 ==> size: 1, diffs:[282]
# 	cust-32 ~ cust-28 ~ prod-6 ==> size: 2, diffs:[ 24 197]
# 	cust-32 ~ cust-28 ~ prod-7 ==> size: 3, diffs:[ 68 185 345]
# (33, 5) ->
#
# 	cust-33 ~ cust-5 ~ prod-1 ==> size: 1, diffs:[40]
# 	cust-33 ~ cust-5 ~ prod-6 ==> size: 3, diffs:[  2  56 187]
# 	cust-33 ~ cust-5 ~ prod-7 ==> size: 4, diffs:[ 43  95 101]
# 	cust-33 ~ cust-5 ~ prod-9 ==> size: 3, diffs:[ 61 227 254]
# (33, 8) ->
#
# 	cust-33 ~ cust-8 ~ prod-6 ==> size: 2, diffs:[ 12 248]
# 	cust-33 ~ cust-8 ~ prod-7 ==> size: 4, diffs:[ 40 123 178]
# 	cust-33 ~ cust-8 ~ prod-9 ==> size: 3, diffs:[ 59 225 252]
# (33, 26) ->
#
# 	cust-33 ~ cust-26 ~ prod-1 ==> size: 1, diffs:[93]
# 	cust-33 ~ cust-26 ~ prod-6 ==> size: 1, diffs:[33]
# 	cust-33 ~ cust-26 ~ prod-7 ==> size: 2, diffs:[ 29 167]
# 	cust-33 ~ cust-26 ~ prod-9 ==> size: 3, diffs:[ 22 188 215]
# (33, 27) ->
#
# 	cust-33 ~ cust-27 ~ prod-1 ==> size: 1, diffs:[42]
# 	cust-33 ~ cust-27 ~ prod-4 ==> size: 1, diffs:[24]
# 	cust-33 ~ cust-27 ~ prod-5 ==> size: 2, diffs:[30 38]
# 	cust-33 ~ cust-27 ~ prod-7 ==> size: 2, diffs:[ 14 152]
# 	cust-33 ~ cust-27 ~ prod-9 ==> size: 9, diffs:[28 37 55]
# (34, 0) ->
#
# 	cust-34 ~ cust-0 ~ prod-4 ==> size: 1, diffs:[15]
# 	cust-34 ~ cust-0 ~ prod-6 ==> size: 4, diffs:[ 54  84 199]
# (34, 7) ->
#
# 	cust-34 ~ cust-7 ~ prod-0 ==> size: 8, diffs:[ 18  53 104]
# 	cust-34 ~ cust-7 ~ prod-5 ==> size: 1, diffs:[206]
# 	cust-34 ~ cust-7 ~ prod-7 ==> size: 2, diffs:[27 82]
# 	cust-34 ~ cust-7 ~ prod-9 ==> size: 4, diffs:[  9  36 281]
# (34, 21) ->
#
# 	cust-34 ~ cust-21 ~ prod-4 ==> size: 2, diffs:[ 13 128]
# 	cust-34 ~ cust-21 ~ prod-5 ==> size: 2, diffs:[16 43]
# 	cust-34 ~ cust-21 ~ prod-6 ==> size: 4, diffs:[  5  43 102]
# 	cust-34 ~ cust-21 ~ prod-9 ==> size: 2, diffs:[259 286]
# (34, 27) ->
#
# 	cust-34 ~ cust-27 ~ prod-4 ==> size: 1, diffs:[97]
# 	cust-34 ~ cust-27 ~ prod-5 ==> size: 1, diffs:[46]
# 	cust-34 ~ cust-27 ~ prod-7 ==> size: 2, diffs:[157 212]
# 	cust-34 ~ cust-27 ~ prod-9 ==> size: 6, diffs:[12 39 53]

# %%
c1_sales.ravel()
# Out:
# array([23, 50])
