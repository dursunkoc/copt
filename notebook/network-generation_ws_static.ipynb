# %%
import sys
import os
sys.path.insert(0, os.path.abspath('../src'))
import model_parameters as MP
import numpy as np
import networkx as nx
from networkx.algorithms.centrality import betweenness_centrality as BC
from networkx.algorithms.centrality import degree_centrality as DC
import matplotlib.pyplot as plt
import pandas as pd
import networkx.algorithms.centrality as nxac
import math

# %%
from docplex.mp.model import Model
from time import time
from experiment.network_generator import gen_network
import numpy as np


def solve_network_model(a_uv, U, e_u):
    start_time = time()
    print("Starting Model: ")
    mdl = Model(name='Network Optimization')
    X = {u: mdl.binary_var(f"X_u:{u}")
                for u in range(0,U)}

    mdl.minimize(mdl.sum([ X[u] for u in range(0,U) ]))

    mdl.add_constraints(
            1 <= mdl.sum((X[u]) + (mdl.sum(X[v] * a_uv[u,v] for v in range(0,U) if a_uv[u,v]==1)))
            for u in range(0,U) if e_u[u]!=0
    )
    mdl.add_constraints(
            (X[u] <= 0 for u in range(0,U) if e_u[u]==0)
    )

    end_time = time()
    print("Started Model: "+str(end_time - start_time))

    start_time = time()
    print("Solving Model: "+str(start_time - end_time))
    result = mdl.solve(log_output=False)
    end_time = time()

    X_u = np.zeros(U, dtype='int')
    if result is not None and result.as_name_dict() is not None:
        for ky,_ in result.as_name_dict().items():
            exec(f'X_u{[int(i.split(":")[1]) for i in ky.split("_")[1:]]} = 1', {}, {'X_u':X_u})
    return X_u

# %%
def max_degree(grph):
    nn = max(grph.degree, key=lambda x: x[1])
    grph.remove_node(nn[0])
    return nn[0]

def max_degree_b(grph, seen, X_u):
    dd = {gd[0]:gd[1]*X_u[gd[0]] for gd in grph.degree}
    max_val = max(dd.items(), key=lambda x: x[1])[1]
    nns = [n for n in dd.items() if n[1] == max_val]
    nns_ = [n for n in nns if n[0] not in seen]
    if len(nns_)>0:
        nn = nns_[0]
    else:
        nn = nns[0]
    neighbors = grph.neighbors(nn[0])
    grph.remove_node(nn[0])
    seen |= set(list(neighbors))
    return (nn[0], seen)

def sort_nodes_to_inc_span(grph, X_u):
    result=list()
    seen = set()
    for _ in range(len(grph.degree)):
        elem, seen = max_degree_b(grph, seen, X_u)
        result.append(elem)
    return result

# %%
g = nx.Graph()
for i in range(1,50):
    g.add_node(i)
g.add_edge(3,6)
g.add_edge(4,7)
g.add_edge(4,28)
g.add_edge(5,8)
g.add_edge(6,45)
g.add_edge(7,8)
g.add_edge(7,22)
g.add_edge(9,11)
g.add_edge(9,20)
g.add_edge(9,43)
g.add_edge(10,29)
g.add_edge(10,35)
g.add_edge(10,48)
g.add_edge(11,19)
g.add_edge(13,20)
g.add_edge(15,17)
g.add_edge(21,28)
g.add_edge(22,38)
g.add_edge(31,45)
g.add_edge(35,10)

# %%
#N_i_j, g = gen_network(n=50, seed=1, net_type='barabasi', m=4, p=None, drop_prob=.9)

plt.style.use('classic')
colors = ['skyblue' for nd in g.nodes]
l_colors = ['red' for nd in g.nodes]
for layout in [ #nx.bipartite_layout(g),
    #nx.fruchterman_reingold_layout(g, k=4/5, iterations=90, scale=5),
#    nx.fruchterman_reingold_layout(g, k=3/4, iterations=90, scale=3),
#    nx.fruchterman_reingold_layout(g, k=2/3, iterations=90, scale=1.9),
#    nx.fruchterman_reingold_layout(g, k=1/2, iterations=90, scale=1.9),
#    nx.fruchterman_reingold_layout(g, k=1/3, iterations=90, scale=1.9),
#    nx.fruchterman_reingold_layout(g, k=1/4, iterations=90, scale=1.9),
#    nx.fruchterman_reingold_layout(g, k=1/5, iterations=90, scale=1.9),
#    nx.fruchterman_reingold_layout(g, k=1/6, iterations=90, scale=1.9),
     nx.spring_layout(g, k=5/math.sqrt(g.order()), iterations=90, scale=1),
    ]:
    nx.draw(g, node_color=colors, node_size=310, pos=layout, with_labels=True)
    latex_code = nx.to_latex(g, node_options={"node_color": colors, "node_size":350, "with_labels": True}, pos=layout)
    plt.show()
    print(g.edges())
    print(latex_code)
#print(latex_code)
# Out:
# [(3, 6), (4, 7), (4, 28), (5, 8), (6, 45), (7, 8), (7, 22), (9, 11), (9, 20), (9, 43), (10, 29), (10, 35), (10, 48), (11, 19), (13, 20), (15, 17), (21, 28), (22, 38), (31, 45)]
# \documentclass{report}
# \usepackage{tikz}
# \usepackage{subcaption}
#
# \begin{document}
# \begin{figure}
#   \begin{tikzpicture}
#       \draw
#         (0.986, 0.18) node (1){1}
#         (0.493, -0.866) node (2){2}
#         (0.255, 0.082) node (3){3}
#         (0.328, -0.594) node (4){4}
#         (-0.259, -0.803) node (5){5}
#         (0.192, 0.383) node (6){6}
#         (0.025, -0.613) node (7){7}
#         (-0.157, -0.568) node (8){8}
#         (0.895, -0.021) node (9){9}
#         (-0.693, -0.198) node (10){10}
#         (0.696, 0.207) node (11){11}
#         (0.351, 0.914) node (12){12}
#         (0.632, -0.225) node (13){13}
#         (0.197, -0.893) node (14){14}
#         (-0.685, 0.12) node (15){15}
#         (-0.718, 0.683) node (16){16}
#         (-0.984, 0.07) node (17){17}
#         (-0.023, 1.0) node (18){18}
#         (0.697, 0.432) node (19){19}
#         (0.862, -0.226) node (20){20}
#         (0.655, -0.122) node (21){21}
#         (-0.253, -0.682) node (22){22}
#         (-0.298, 0.975) node (23){23}
#         (-0.785, -0.579) node (24){24}
#         (-0.956, 0.334) node (25){25}
#         (-0.531, 0.725) node (26){26}
#         (-0.917, -0.452) node (27){27}
#         (0.559, -0.425) node (28){28}
#         (-0.45, -0.146) node (29){29}
#         (-0.498, 0.866) node (30){30}
#         (0.051, 0.877) node (31){31}
#         (0.852, 0.527) node (32){32}
#         (0.629, -0.732) node (33){33}
#         (0.898, 0.34) node (34){34}
#         (-0.772, -0.031) node (35){35}
#         (-0.982, -0.244) node (36){36}
#         (0.587, 0.846) node (37){37}
#         (-0.443, -0.863) node (38){38}
#         (-0.213, -0.898) node (39){39}
#         (-0.954, 0.171) node (40){40}
#         (0.174, 0.929) node (41){41}
#         (-0.797, 0.51) node (42){42}
#         (0.947, 0.034) node (43){43}
#         (0.929, -0.352) node (44){44}
#         (0.129, 0.663) node (45){45}
#         (-0.6, -0.723) node (46){46}
#         (0.737, 0.708) node (47){47}
#         (-0.757, -0.371) node (48){48}
#         (-0.032, -0.951) node (49){49};
#       \begin{scope}[-]
#         \draw (3) to (6);
#         \draw (4) to (7);
#         \draw (4) to (28);
#         \draw (5) to (8);
#         \draw (6) to (45);
#         \draw (7) to (8);
#         \draw (7) to (22);
#         \draw (9) to (11);
#         \draw (9) to (20);
#         \draw (9) to (43);
#         \draw (10) to (29);
#         \draw (10) to (35);
#         \draw (10) to (48);
#         \draw (11) to (19);
#         \draw (13) to (20);
#         \draw (15) to (17);
#         \draw (21) to (28);
#         \draw (22) to (38);
#         \draw (31) to (45);
#       \end{scope}
#     \end{tikzpicture}
# \end{figure}
# \end{document}

# %%
X_cuhd = np.zeros((1,50,1,1), dtype='int')
a_uv, g = gen_network(n=50, seed=1, net_type='barabasi', m=4, p=None, drop_prob=.9)
X_u = solve_network_model(a_uv=a_uv, U=50, e_u=np.ones(50))
N_i_j, g = gen_network(n=50, seed=1, net_type='barabasi', m=4, p=None, drop_prob=.9)
plt.style.use('classic')
sp = sort_nodes_to_inc_span(g, X_u)
# Out:
# Starting Model:
# Started Model: 0.18402504920959473
# Solving Model: 0.00019502639770507812

# %%
N_i_j, g = gen_network(n=50, seed=1, net_type='barabasi', m=4, p=None, drop_prob=.9)
plt.style.use('classic')
for i,p in enumerate(sp):
    colors = ['tab:red' if nd == p  else 'tab:blue' for nd in g.nodes]
    nx.draw(g, node_color=colors, pos=nx.fruchterman_reingold_layout(g, k=1/4), with_labels=True)
    g.remove_node(p)
    plt.show()

# %%
fig,ax = plt.subplots(figsize=(8, 4))

d = nx.Graph()
d.add_node(100, pos=(1,5))
dpos=nx.get_node_attributes(d,'pos')
nx.draw(d, pos=dpos, with_labels=False, node_size=0)

sna = nx.Graph()
sna.add_node(1, pos=(1,3))
sna.add_node(2, pos=(1,1))
sna.add_node(3, pos=(2,2))
sna.add_node(4, pos=(3,3))
sna.add_node(5, pos=(3,1))
sna.add_node(6, pos=(4,1))
sna.add_edge(1,4)
sna.add_edge(1,3)
sna.add_edge(2,3)
sna.add_edge(2,5)

pos=nx.get_node_attributes(sna,'pos')

nx.draw(sna, pos=pos, with_labels=True)

tsna = nx.Graph()
tsna.add_node(1, pos=(9,3))
tsna.add_node(2, pos=(9,1))
tsna.add_node(3, pos=(10,2))
tsna.add_node(4, pos=(11,3))
tsna.add_node(5, pos=(11,1))
tsna.add_node(6, pos=(12,1))
tsna.add_edge(1,4)
#tsna.add_edge(1,3)
tsna.add_edge(2,3)
tsna.add_edge(2,5)

tpos=nx.get_node_attributes(tsna,'pos')

nx.draw(tsna, pos=tpos, with_labels=True)

ax.text(
    .13,
    .7,
    """Social Network with 
CDR only""",
    transform=ax.transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="w", alpha=0.5),
    ha="center"
)

ax.text(
    .85,
    .7,
    """Updated Social Network with 
CDR and Tariff-Change Data""",
    transform=ax.transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="w", alpha=0.5),
    wrap=True,ha='center'
)
# Out:
# Text(0.85, 0.7, 'Updated Social Network with \nCDR and Tariff-Change Data')

# %%
nx.get_node_attributes(sna, 'pos')

# %%
fig,ax = plt.subplots(figsize=(8, 4))

d = nx.Graph()
d.add_node(100, pos=(4,5))
dpos=nx.get_node_attributes(d,'pos')
nx.draw(d, pos=dpos, with_labels=False, node_size=0)

sna = nx.Graph()
sna.add_node(1, pos=(1,5))
sna.add_node(2, pos=(1,4))
sna.add_node(3, pos=(1,3))
sna.add_node(4, pos=(1,2))
sna.add_node(5, pos=(1,1))
sna.add_node(6, pos=(2,5))
sna.add_node(7, pos=(2,4))
sna.add_node(8, pos=(2,3))
sna.add_node(9, pos=(2,2))
sna.add_node(0, pos=(2,1))




pos=nx.get_node_attributes(sna,'pos')

nx.draw(sna, pos=pos, with_labels=True)
